# %% [markdown]
# # Exploratory Text Analytics Final Project

# %%
import numpy as np
import pandas as pd
import os
import json
import dotenv
import requests
import lyricsgenius
import base64

# %% [markdown]
# ## Lyrics Genius API Calls
# ### Read .env for API tokens

# %%
dotenv.load_dotenv()
geniusclientid = os.getenv('geniusclientid')
geniusclientsecret = os.getenv('geniusclientsecret')
geniusclientaccesstoken = os.getenv('geniusclientaccesstoken')
spotifyclientid = os.getenv('spotifyclientid')
spotifyclientsecret = os.getenv('spotifyclientsecret')

# %% [markdown]
# ### Lyrics Genius Requests

# %%
genius = lyricsgenius.Genius(geniusclientaccesstoken)
artist = genius.search_artist('St. Vincent', max_songs=3)
# Out:
# Searching for songs by St. Vincent...
#
# Song 1: "Los Ageless"
# Song 2: "New York"
# Song 3: "Prince Johnny"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.

# %% [markdown]
# The wrapper `lyricsgenius` is a little slow. Let's try calling the api directly

# %%
# headers
r = requests.get('https://httpbin.org/user-agent')
useragent = json.loads(r.text)['user-agent']
headers = {'User-Agent':useragent,
           'From':'rhl8pk@virginia.edu'}

# %%
root = 'https://api.genius.com'
endpoint = '/search?'
parameters = {'access_token':geniusclientaccesstoken,
              'q':'St. Vincent'}
r = requests.get(root+endpoint, params=parameters, headers=headers)
r
# Out:
# <Response [200]>

# %%
myjson = json.loads(r.text)
myjson
# Out:
# {'meta': {'status': 200},
#  'response': {'hits': [{'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 9,
#      'api_path': '/songs/66160',
#      'artist_names': 'Bon Iver & St. Vincent',
#      'full_title': 'Rosyln by\xa0Bon\xa0Iver & St. Vincent',
#      'header_image_thumbnail_url': 'https://images.genius.com/9ee556816f731ec19f706cd65abe509a.300x300x1.png',
#      'header_image_url': 'https://images.genius.com/9ee556816f731ec19f706cd65abe509a.1000x1000x1.png',
#      'id': 66160,
#      'lyrics_owner_id': 27148,
#      'lyrics_state': 'complete',
#      'path': '/Bon-iver-and-st-vincent-rosyln-lyrics',
#      'pyongs_count': 44,
#      'relationships_index_url': 'https://genius.com/Bon-iver-and-st-vincent-rosyln-sample',
#      'release_date_components': {'year': 2009, 'month': 10, 'day': 16},
#      'release_date_for_display': 'October 16, 2009',
#      'release_date_with_abbreviated_month_for_display': 'Oct. 16, 2009',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/9ee556816f731ec19f706cd65abe509a.300x300x1.png',
#      'song_art_image_url': 'https://images.genius.com/9ee556816f731ec19f706cd65abe509a.1000x1000x1.png',
#      'stats': {'unreviewed_annotations': 3, 'hot': False, 'pageviews': 340003},
#      'title': 'Rosyln',
#      'title_with_featured': 'Rosyln',
#      'url': 'https://genius.com/Bon-iver-and-st-vincent-rosyln-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/351326',
#       'header_image_url': 'https://images.genius.com/88c69da0be1897535bd596efcc021794.696x696x1.jpg',
#       'id': 351326,
#       'image_url': 'https://images.genius.com/88c69da0be1897535bd596efcc021794.696x696x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Bon Iver & St. Vincent',
#       'url': 'https://genius.com/artists/Bon-iver-and-st-vincent'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 13,
#      'api_path': '/songs/3222021',
#      'artist_names': 'St. Vincent',
#      'full_title': 'Los Ageless by\xa0St.\xa0Vincent',
#      'header_image_thumbnail_url': 'https://images.genius.com/15df0a20323caf48897c7cae8ab838ed.300x191x1.jpg',
#      'header_image_url': 'https://images.genius.com/15df0a20323caf48897c7cae8ab838ed.1000x635x1.jpg',
#      'id': 3222021,
#      'lyrics_owner_id': 3262439,
#      'lyrics_state': 'complete',
#      'path': '/St-vincent-los-ageless-lyrics',
#      'pyongs_count': 18,
#      'relationships_index_url': 'https://genius.com/St-vincent-los-ageless-sample',
#      'release_date_components': {'year': 2017, 'month': 9, 'day': 6},
#      'release_date_for_display': 'September 6, 2017',
#      'release_date_with_abbreviated_month_for_display': 'Sep. 6, 2017',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/87fc67d260d795522c132122cd748fab.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/87fc67d260d795522c132122cd748fab.999x1000x1.jpg',
#      'stats': {'unreviewed_annotations': 0, 'hot': False, 'pageviews': 154111},
#      'title': 'Los Ageless',
#      'title_with_featured': 'Los Ageless',
#      'url': 'https://genius.com/St-vincent-los-ageless-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/2373',
#       'header_image_url': 'https://images.genius.com/47dcc306f147ae9274fdb412475de47e.1000x333x1.png',
#       'id': 2373,
#       'image_url': 'https://images.genius.com/62c16bcc41c6e7649ecb7c067da7fd40.932x932x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'St. Vincent',
#       'url': 'https://genius.com/artists/St-vincent'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 11,
#      'api_path': '/songs/3137734',
#      'artist_names': 'St. Vincent',
#      'full_title': 'New York by\xa0St.\xa0Vincent',
#      'header_image_thumbnail_url': 'https://images.genius.com/96811dcc479016b046c8856bd26ba016.300x200x1.jpg',
#      'header_image_url': 'https://images.genius.com/96811dcc479016b046c8856bd26ba016.1000x667x1.jpg',
#      'id': 3137734,
#      'lyrics_owner_id': 2558324,
#      'lyrics_state': 'complete',
#      'path': '/St-vincent-new-york-lyrics',
#      'pyongs_count': 23,
#      'relationships_index_url': 'https://genius.com/St-vincent-new-york-sample',
#      'release_date_components': {'year': 2017, 'month': 6, 'day': 30},
#      'release_date_for_display': 'June 30, 2017',
#      'release_date_with_abbreviated_month_for_display': 'Jun. 30, 2017',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/3398b87b45b0731831e07162f907545a.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/3398b87b45b0731831e07162f907545a.1000x1000x1.jpg',
#      'stats': {'unreviewed_annotations': 0, 'hot': False, 'pageviews': 137794},
#      'title': 'New York',
#      'title_with_featured': 'New York',
#      'url': 'https://genius.com/St-vincent-new-york-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/2373',
#       'header_image_url': 'https://images.genius.com/47dcc306f147ae9274fdb412475de47e.1000x333x1.png',
#       'id': 2373,
#       'image_url': 'https://images.genius.com/62c16bcc41c6e7649ecb7c067da7fd40.932x932x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'St. Vincent',
#       'url': 'https://genius.com/artists/St-vincent'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 17,
#      'api_path': '/songs/353631',
#      'artist_names': 'St. Vincent',
#      'full_title': 'Prince Johnny by\xa0St.\xa0Vincent',
#      'header_image_thumbnail_url': 'https://images.genius.com/fdf1825250a30e5624c651687cc6b7cc.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/fdf1825250a30e5624c651687cc6b7cc.770x770x1.jpg',
#      'id': 353631,
#      'lyrics_owner_id': 398309,
#      'lyrics_state': 'complete',
#      'path': '/St-vincent-prince-johnny-lyrics',
#      'pyongs_count': 21,
#      'relationships_index_url': 'https://genius.com/St-vincent-prince-johnny-sample',
#      'release_date_components': {'year': 2014, 'month': 2, 'day': 24},
#      'release_date_for_display': 'February 24, 2014',
#      'release_date_with_abbreviated_month_for_display': 'Feb. 24, 2014',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/fdf1825250a30e5624c651687cc6b7cc.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/fdf1825250a30e5624c651687cc6b7cc.770x770x1.jpg',
#      'stats': {'unreviewed_annotations': 0, 'hot': False, 'pageviews': 110022},
#      'title': 'Prince Johnny',
#      'title_with_featured': 'Prince Johnny',
#      'url': 'https://genius.com/St-vincent-prince-johnny-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/2373',
#       'header_image_url': 'https://images.genius.com/47dcc306f147ae9274fdb412475de47e.1000x333x1.png',
#       'id': 2373,
#       'image_url': 'https://images.genius.com/62c16bcc41c6e7649ecb7c067da7fd40.932x932x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'St. Vincent',
#       'url': 'https://genius.com/artists/St-vincent'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 18,
#      'api_path': '/songs/333443',
#      'artist_names': 'St. Vincent',
#      'full_title': 'Digital Witness by\xa0St.\xa0Vincent',
#      'header_image_thumbnail_url': 'https://images.genius.com/0e8b365dbfe049b63ebb41f859cd31a1.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/0e8b365dbfe049b63ebb41f859cd31a1.562x562x1.jpg',
#      'id': 333443,
#      'lyrics_owner_id': 125524,
#      'lyrics_state': 'complete',
#      'path': '/St-vincent-digital-witness-lyrics',
#      'pyongs_count': 38,
#      'relationships_index_url': 'https://genius.com/St-vincent-digital-witness-sample',
#      'release_date_components': {'year': 2014, 'month': 1, 'day': 6},
#      'release_date_for_display': 'January 6, 2014',
#      'release_date_with_abbreviated_month_for_display': 'Jan. 6, 2014',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/0e8b365dbfe049b63ebb41f859cd31a1.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/0e8b365dbfe049b63ebb41f859cd31a1.562x562x1.jpg',
#      'stats': {'unreviewed_annotations': 2, 'hot': False, 'pageviews': 97415},
#      'title': 'Digital Witness',
#      'title_with_featured': 'Digital Witness',
#      'url': 'https://genius.com/St-vincent-digital-witness-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/2373',
#       'header_image_url': 'https://images.genius.com/47dcc306f147ae9274fdb412475de47e.1000x333x1.png',
#       'id': 2373,
#       'image_url': 'https://images.genius.com/62c16bcc41c6e7649ecb7c067da7fd40.932x932x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'St. Vincent',
#       'url': 'https://genius.com/artists/St-vincent'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 13,
#      'api_path': '/songs/3225251',
#      'artist_names': 'St. Vincent',
#      'full_title': 'Masseduction by\xa0St.\xa0Vincent',
#      'header_image_thumbnail_url': 'https://images.genius.com/2298ec142d9ab4f709cf096541c88ad8.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/2298ec142d9ab4f709cf096541c88ad8.1000x1000x1.jpg',
#      'id': 3225251,
#      'lyrics_owner_id': 319713,
#      'lyrics_state': 'complete',
#      'path': '/St-vincent-masseduction-lyrics',
#      'pyongs_count': 10,
#      'relationships_index_url': 'https://genius.com/St-vincent-masseduction-sample',
#      'release_date_components': {'year': 2017, 'month': 10, 'day': 13},
#      'release_date_for_display': 'October 13, 2017',
#      'release_date_with_abbreviated_month_for_display': 'Oct. 13, 2017',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/2298ec142d9ab4f709cf096541c88ad8.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/2298ec142d9ab4f709cf096541c88ad8.1000x1000x1.jpg',
#      'stats': {'unreviewed_annotations': 1, 'hot': False, 'pageviews': 108898},
#      'title': 'Masseduction',
#      'title_with_featured': 'Masseduction',
#      'url': 'https://genius.com/St-vincent-masseduction-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/2373',
#       'header_image_url': 'https://images.genius.com/47dcc306f147ae9274fdb412475de47e.1000x333x1.png',
#       'id': 2373,
#       'image_url': 'https://images.genius.com/62c16bcc41c6e7649ecb7c067da7fd40.932x932x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'St. Vincent',
#       'url': 'https://genius.com/artists/St-vincent'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 10,
#      'api_path': '/songs/295230',
#      'artist_names': 'St. Vincent',
#      'full_title': 'Birth in Reverse by\xa0St.\xa0Vincent',
#      'header_image_thumbnail_url': 'https://images.genius.com/056abd1ed620b8c2f230a6a003005227.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/056abd1ed620b8c2f230a6a003005227.1000x1000x1.jpg',
#      'id': 295230,
#      'lyrics_owner_id': 116340,
#      'lyrics_state': 'complete',
#      'path': '/St-vincent-birth-in-reverse-lyrics',
#      'pyongs_count': 15,
#      'relationships_index_url': 'https://genius.com/St-vincent-birth-in-reverse-sample',
#      'release_date_components': {'year': 2013, 'month': 12, 'day': 10},
#      'release_date_for_display': 'December 10, 2013',
#      'release_date_with_abbreviated_month_for_display': 'Dec. 10, 2013',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/056abd1ed620b8c2f230a6a003005227.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/056abd1ed620b8c2f230a6a003005227.1000x1000x1.jpg',
#      'stats': {'unreviewed_annotations': 2, 'hot': False, 'pageviews': 80848},
#      'title': 'Birth in Reverse',
#      'title_with_featured': 'Birth in Reverse',
#      'url': 'https://genius.com/St-vincent-birth-in-reverse-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/2373',
#       'header_image_url': 'https://images.genius.com/47dcc306f147ae9274fdb412475de47e.1000x333x1.png',
#       'id': 2373,
#       'image_url': 'https://images.genius.com/62c16bcc41c6e7649ecb7c067da7fd40.932x932x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'St. Vincent',
#       'url': 'https://genius.com/artists/St-vincent'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 12,
#      'api_path': '/songs/3225253',
#      'artist_names': 'St. Vincent',
#      'full_title': 'Happy Birthday, Johnny by\xa0St.\xa0Vincent',
#      'header_image_thumbnail_url': 'https://images.genius.com/2298ec142d9ab4f709cf096541c88ad8.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/2298ec142d9ab4f709cf096541c88ad8.1000x1000x1.jpg',
#      'id': 3225253,
#      'lyrics_owner_id': 4795333,
#      'lyrics_state': 'complete',
#      'path': '/St-vincent-happy-birthday-johnny-lyrics',
#      'pyongs_count': 10,
#      'relationships_index_url': 'https://genius.com/St-vincent-happy-birthday-johnny-sample',
#      'release_date_components': {'year': 2017, 'month': 10, 'day': 13},
#      'release_date_for_display': 'October 13, 2017',
#      'release_date_with_abbreviated_month_for_display': 'Oct. 13, 2017',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/2298ec142d9ab4f709cf096541c88ad8.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/2298ec142d9ab4f709cf096541c88ad8.1000x1000x1.jpg',
#      'stats': {'unreviewed_annotations': 1, 'hot': False, 'pageviews': 91296},
#      'title': 'Happy Birthday, Johnny',
#      'title_with_featured': 'Happy Birthday, Johnny',
#      'url': 'https://genius.com/St-vincent-happy-birthday-johnny-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/2373',
#       'header_image_url': 'https://images.genius.com/47dcc306f147ae9274fdb412475de47e.1000x333x1.png',
#       'id': 2373,
#       'image_url': 'https://images.genius.com/62c16bcc41c6e7649ecb7c067da7fd40.932x932x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'St. Vincent',
#       'url': 'https://genius.com/artists/St-vincent'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 20,
#      'api_path': '/songs/3222023',
#      'artist_names': 'St. Vincent',
#      'full_title': 'Pills by\xa0St.\xa0Vincent',
#      'header_image_thumbnail_url': 'https://images.genius.com/1caf0ca221ffa1590830864ab6384a66.300x169x1.jpg',
#      'header_image_url': 'https://images.genius.com/1caf0ca221ffa1590830864ab6384a66.1000x563x1.jpg',
#      'id': 3222023,
#      'lyrics_owner_id': 319713,
#      'lyrics_state': 'complete',
#      'path': '/St-vincent-pills-lyrics',
#      'pyongs_count': 12,
#      'relationships_index_url': 'https://genius.com/St-vincent-pills-sample',
#      'release_date_components': {'year': 2017, 'month': 10, 'day': 10},
#      'release_date_for_display': 'October 10, 2017',
#      'release_date_with_abbreviated_month_for_display': 'Oct. 10, 2017',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/24490c57b01cc94ac32888a2c28e6588.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/24490c57b01cc94ac32888a2c28e6588.1000x1000x1.jpg',
#      'stats': {'unreviewed_annotations': 2, 'hot': False, 'pageviews': 84358},
#      'title': 'Pills',
#      'title_with_featured': 'Pills',
#      'url': 'https://genius.com/St-vincent-pills-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/2373',
#       'header_image_url': 'https://images.genius.com/47dcc306f147ae9274fdb412475de47e.1000x333x1.png',
#       'id': 2373,
#       'image_url': 'https://images.genius.com/62c16bcc41c6e7649ecb7c067da7fd40.932x932x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'St. Vincent',
#       'url': 'https://genius.com/artists/St-vincent'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 5,
#      'api_path': '/songs/3225261',
#      'artist_names': 'St. Vincent',
#      'full_title': 'Slow Disco by\xa0St.\xa0Vincent',
#      'header_image_thumbnail_url': 'https://images.genius.com/2298ec142d9ab4f709cf096541c88ad8.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/2298ec142d9ab4f709cf096541c88ad8.1000x1000x1.jpg',
#      'id': 3225261,
#      'lyrics_owner_id': 319713,
#      'lyrics_state': 'complete',
#      'path': '/St-vincent-slow-disco-lyrics',
#      'pyongs_count': 10,
#      'relationships_index_url': 'https://genius.com/St-vincent-slow-disco-sample',
#      'release_date_components': {'year': 2017, 'month': 10, 'day': 13},
#      'release_date_for_display': 'October 13, 2017',
#      'release_date_with_abbreviated_month_for_display': 'Oct. 13, 2017',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/2298ec142d9ab4f709cf096541c88ad8.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/2298ec142d9ab4f709cf096541c88ad8.1000x1000x1.jpg',
#      'stats': {'unreviewed_annotations': 0, 'hot': False, 'pageviews': 75702},
#      'title': 'Slow Disco',
#      'title_with_featured': 'Slow Disco',
#      'url': 'https://genius.com/St-vincent-slow-disco-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/2373',
#       'header_image_url': 'https://images.genius.com/47dcc306f147ae9274fdb412475de47e.1000x333x1.png',
#       'id': 2373,
#       'image_url': 'https://images.genius.com/62c16bcc41c6e7649ecb7c067da7fd40.932x932x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'St. Vincent',
#       'url': 'https://genius.com/artists/St-vincent'}}}]}}

# %%
myjson['response']['hits'][1]['result']['primary_artist']['api_path']
# Out:
# '/artists/2373'

# %% [markdown]
# ### Loop over artist list to get IDs for more in-depth API calls

# %%
artist_list = [
'St. Vincent', 
'LCD Soundsystem',
'Dirty Projectors',
'Ava Luna', 
'Caroline Polachek', 
'Mr. Twin Sister', 
'The Marias', 
'Pure Bathing Culture',
'Cults', 
'The National', 
'Ethel Cain',
'CHVRCHES', 
'Big Thief', 
'Holychild', 
'Yeah Yeah Yeahs', 
'MGMT', 
'Radiohead', 
'Metric', 
'Broken Social Scene'
]

# %%
artist_endpoints = {}
for artist in artist_list:
    parameters = {'access_token':geniusclientaccesstoken,
              'q':artist}
    r = requests.get(root+endpoint, params=parameters, headers=headers)
    myjson = json.loads(r.text)
    parsed_endpoint = myjson['response']['hits'][1]['result']['primary_artist']['api_path']
    genius_name = myjson['response']['hits'][1]['result']['primary_artist']['name']
    artist_endpoints[artist] = parsed_endpoint
    print(f'{artist} matched to {genius_name}. Endpoint: {parsed_endpoint}')
# Out:
# St. Vincent matched to St. Vincent. Endpoint: /artists/2373
# LCD Soundsystem matched to LCD Soundsystem. Endpoint: /artists/1169
# Dirty Projectors matched to Dirty Projectors. Endpoint: /artists/12968
# Ava Luna matched to Ava Luna. Endpoint: /artists/390647
# Caroline Polachek matched to Caroline Polachek. Endpoint: /artists/63882
# Mr. Twin Sister matched to Mr Twin Sister. Endpoint: /artists/230800
# The Marias matched to The Marías. Endpoint: /artists/1127174
# Pure Bathing Culture matched to Pure Bathing Culture. Endpoint: /artists/216604
# Cults matched to Cults. Endpoint: /artists/15724
# The National matched to The National. Endpoint: /artists/658
# Ethel Cain matched to Ethel Cain. Endpoint: /artists/1904291
# CHVRCHES matched to CHVRCHES. Endpoint: /artists/40863
# Big Thief matched to Big Thief. Endpoint: /artists/668810
# Holychild matched to HOLYCHILD. Endpoint: /artists/309275
# Yeah Yeah Yeahs matched to Yeah Yeah Yeahs. Endpoint: /artists/17657
# MGMT matched to MGMT. Endpoint: /artists/764
# Radiohead matched to Radiohead. Endpoint: /artists/604
# Metric matched to Metrickz. Endpoint: /artists/20541
# Broken Social Scene matched to Broken Social Scene. Endpoint: /artists/30848

# %% [markdown]
# Looks like everyone matched except for Metric. Let's scope the JSON for their artist search

# %%
endpoint = '/search?'
parameters = {'access_token':geniusclientaccesstoken,
              'q':'Metric'}
r = requests.get(root+endpoint, params=parameters, headers=headers)
myjson = json.loads(r.text)
myjson
# Out:
# {'meta': {'status': 200},
#  'response': {'hits': [{'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 11,
#      'api_path': '/songs/121943',
#      'artist_names': 'Metric',
#      'full_title': 'Black Sheep by\xa0Metric',
#      'header_image_thumbnail_url': 'https://images.genius.com/921bc72852619829d6fd80f55bb47c3a.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/921bc72852619829d6fd80f55bb47c3a.1000x1000x1.jpg',
#      'id': 121943,
#      'lyrics_owner_id': 131,
#      'lyrics_state': 'complete',
#      'path': '/Metric-black-sheep-lyrics',
#      'pyongs_count': 29,
#      'relationships_index_url': 'https://genius.com/Metric-black-sheep-sample',
#      'release_date_components': {'year': 2010, 'month': 8, 'day': 10},
#      'release_date_for_display': 'August 10, 2010',
#      'release_date_with_abbreviated_month_for_display': 'Aug. 10, 2010',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/b5ff8bf8f3e07cf5a318e90e032cd395.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/b5ff8bf8f3e07cf5a318e90e032cd395.640x640x1.jpg',
#      'stats': {'unreviewed_annotations': 7, 'hot': False, 'pageviews': 305916},
#      'title': 'Black Sheep',
#      'title_with_featured': 'Black Sheep',
#      'url': 'https://genius.com/Metric-black-sheep-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/17675',
#       'header_image_url': 'https://images.genius.com/109f36066e74d2fd7af65356fcc5f9c0.1000x667x1.jpg',
#       'id': 17675,
#       'image_url': 'https://images.genius.com/c0c4c6f96a97629323551f663ab2f726.667x667x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Metric',
#       'url': 'https://genius.com/artists/Metric'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 7,
#      'api_path': '/songs/235420',
#      'artist_names': 'Metrickz',
#      'full_title': 'Valentina by\xa0Metrickz',
#      'header_image_thumbnail_url': 'https://images.genius.com/07d676459699997d2de0be7e515f3451.300x300x1.png',
#      'header_image_url': 'https://images.genius.com/07d676459699997d2de0be7e515f3451.1000x1000x1.png',
#      'id': 235420,
#      'lyrics_owner_id': 289920,
#      'lyrics_state': 'complete',
#      'path': '/Metrickz-valentina-lyrics',
#      'pyongs_count': 11,
#      'relationships_index_url': 'https://genius.com/Metrickz-valentina-sample',
#      'release_date_components': {'year': 2013, 'month': 10, 'day': 9},
#      'release_date_for_display': 'October 9, 2013',
#      'release_date_with_abbreviated_month_for_display': 'Oct. 9, 2013',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/07d676459699997d2de0be7e515f3451.300x300x1.png',
#      'song_art_image_url': 'https://images.genius.com/07d676459699997d2de0be7e515f3451.1000x1000x1.png',
#      'stats': {'unreviewed_annotations': 2, 'hot': False, 'pageviews': 93657},
#      'title': 'Valentina',
#      'title_with_featured': 'Valentina',
#      'url': 'https://genius.com/Metrickz-valentina-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/20541',
#       'header_image_url': 'https://images.genius.com/d9e65e10bc52a37e922548a98ccf9b8c.1000x400x1.jpg',
#       'id': 20541,
#       'image_url': 'https://images.genius.com/77e38dc764ca197b3105ab0c1270c89a.1000x1000x1.png',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Metrickz',
#       'url': 'https://genius.com/artists/Metrickz'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 6,
#      'api_path': '/songs/1482108',
#      'artist_names': 'Metric (Ft. Brie Larson)',
#      'full_title': 'Black Sheep (Brie Larson Vocal Version) by\xa0Metric (Ft.\xa0Brie\xa0Larson)',
#      'header_image_thumbnail_url': 'https://images.genius.com/7153c26b9b339b82ee5fc48abb4b8c1c.300x169x1.jpg',
#      'header_image_url': 'https://images.genius.com/7153c26b9b339b82ee5fc48abb4b8c1c.1000x563x1.jpg',
#      'id': 1482108,
#      'lyrics_owner_id': 269182,
#      'lyrics_state': 'complete',
#      'path': '/Metric-black-sheep-brie-larson-vocal-version-lyrics',
#      'pyongs_count': 4,
#      'relationships_index_url': 'https://genius.com/Metric-black-sheep-brie-larson-vocal-version-sample',
#      'release_date_components': {'year': 2010, 'month': None, 'day': None},
#      'release_date_for_display': '2010',
#      'release_date_with_abbreviated_month_for_display': '2010',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/2a152b90c3ea7c7c199b0b8e31004036.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/2a152b90c3ea7c7c199b0b8e31004036.640x640x1.jpg',
#      'stats': {'unreviewed_annotations': 5, 'hot': False, 'pageviews': 101890},
#      'title': 'Black Sheep (Brie Larson Vocal Version)',
#      'title_with_featured': 'Black Sheep (Brie Larson Vocal Version) (Ft.\xa0Brie\xa0Larson)',
#      'url': 'https://genius.com/Metric-black-sheep-brie-larson-vocal-version-lyrics',
#      'featured_artists': [{'api_path': '/artists/214714',
#        'header_image_url': 'https://images.genius.com/4c9b29f9e46d19027d800ac214c6bdc0.1000x563x1.jpg',
#        'id': 214714,
#        'image_url': 'https://images.genius.com/d52a40913e3db2749bc65be671294f05.500x500x1.jpg',
#        'is_meme_verified': False,
#        'is_verified': False,
#        'name': 'Brie Larson',
#        'url': 'https://genius.com/artists/Brie-larson'}],
#      'primary_artist': {'api_path': '/artists/17675',
#       'header_image_url': 'https://images.genius.com/109f36066e74d2fd7af65356fcc5f9c0.1000x667x1.jpg',
#       'id': 17675,
#       'image_url': 'https://images.genius.com/c0c4c6f96a97629323551f663ab2f726.667x667x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Metric',
#       'url': 'https://genius.com/artists/Metric'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 13,
#      'api_path': '/songs/290437',
#      'artist_names': 'Metric',
#      'full_title': 'Lost Kitten by\xa0Metric',
#      'header_image_thumbnail_url': 'https://images.genius.com/18e39d6220f1c70b4851d0ddd34062c5.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/18e39d6220f1c70b4851d0ddd34062c5.1000x1000x1.jpg',
#      'id': 290437,
#      'lyrics_owner_id': 309762,
#      'lyrics_state': 'complete',
#      'path': '/Metric-lost-kitten-lyrics',
#      'pyongs_count': 7,
#      'relationships_index_url': 'https://genius.com/Metric-lost-kitten-sample',
#      'release_date_components': {'year': 2012, 'month': 6, 'day': 12},
#      'release_date_for_display': 'June 12, 2012',
#      'release_date_with_abbreviated_month_for_display': 'Jun. 12, 2012',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/18e39d6220f1c70b4851d0ddd34062c5.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/18e39d6220f1c70b4851d0ddd34062c5.1000x1000x1.jpg',
#      'stats': {'unreviewed_annotations': 9, 'hot': False, 'pageviews': 56736},
#      'title': 'Lost Kitten',
#      'title_with_featured': 'Lost Kitten',
#      'url': 'https://genius.com/Metric-lost-kitten-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/17675',
#       'header_image_url': 'https://images.genius.com/109f36066e74d2fd7af65356fcc5f9c0.1000x667x1.jpg',
#       'id': 17675,
#       'image_url': 'https://images.genius.com/c0c4c6f96a97629323551f663ab2f726.667x667x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Metric',
#       'url': 'https://genius.com/artists/Metric'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 7,
#      'api_path': '/songs/66534',
#      'artist_names': 'Metric',
#      'full_title': "Help I'm Alive by\xa0Metric",
#      'header_image_thumbnail_url': 'https://images.rapgenius.com/e7b3c40224d635421257dd8e6b88d36f.300x300x1.jpg',
#      'header_image_url': 'https://images.rapgenius.com/e7b3c40224d635421257dd8e6b88d36f.500x500x1.jpg',
#      'id': 66534,
#      'lyrics_owner_id': 74226,
#      'lyrics_state': 'complete',
#      'path': '/Metric-help-im-alive-lyrics',
#      'pyongs_count': 6,
#      'relationships_index_url': 'https://genius.com/Metric-help-im-alive-sample',
#      'release_date_components': {'year': 2008, 'month': 12, 'day': 23},
#      'release_date_for_display': 'December 23, 2008',
#      'release_date_with_abbreviated_month_for_display': 'Dec. 23, 2008',
#      'song_art_image_thumbnail_url': 'https://images.rapgenius.com/e7b3c40224d635421257dd8e6b88d36f.300x300x1.jpg',
#      'song_art_image_url': 'https://images.rapgenius.com/e7b3c40224d635421257dd8e6b88d36f.500x500x1.jpg',
#      'stats': {'unreviewed_annotations': 0, 'hot': False, 'pageviews': 41228},
#      'title': 'Help I’m Alive',
#      'title_with_featured': "Help I'm Alive",
#      'url': 'https://genius.com/Metric-help-im-alive-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/17675',
#       'header_image_url': 'https://images.genius.com/109f36066e74d2fd7af65356fcc5f9c0.1000x667x1.jpg',
#       'id': 17675,
#       'image_url': 'https://images.genius.com/c0c4c6f96a97629323551f663ab2f726.667x667x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Metric',
#       'url': 'https://genius.com/artists/Metric'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 0,
#      'api_path': '/songs/3929875',
#      'artist_names': 'Metrickz',
#      'full_title': 'Vergissmeinnicht by\xa0Metrickz',
#      'header_image_thumbnail_url': 'https://images.genius.com/b6eb83c752ca54507d6efaa329b6f817.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/b6eb83c752ca54507d6efaa329b6f817.640x640x1.jpg',
#      'id': 3929875,
#      'lyrics_owner_id': 4303832,
#      'lyrics_state': 'complete',
#      'path': '/Metrickz-vergissmeinnicht-lyrics',
#      'pyongs_count': 1,
#      'relationships_index_url': 'https://genius.com/Metrickz-vergissmeinnicht-sample',
#      'release_date_components': {'year': 2018, 'month': 9, 'day': 4},
#      'release_date_for_display': 'September 4, 2018',
#      'release_date_with_abbreviated_month_for_display': 'Sep. 4, 2018',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/b6eb83c752ca54507d6efaa329b6f817.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/b6eb83c752ca54507d6efaa329b6f817.640x640x1.jpg',
#      'stats': {'unreviewed_annotations': 0, 'hot': False, 'pageviews': 30618},
#      'title': 'Vergissmeinnicht',
#      'title_with_featured': 'Vergissmeinnicht',
#      'url': 'https://genius.com/Metrickz-vergissmeinnicht-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/20541',
#       'header_image_url': 'https://images.genius.com/d9e65e10bc52a37e922548a98ccf9b8c.1000x400x1.jpg',
#       'id': 20541,
#       'image_url': 'https://images.genius.com/77e38dc764ca197b3105ab0c1270c89a.1000x1000x1.png',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Metrickz',
#       'url': 'https://genius.com/artists/Metrickz'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 8,
#      'api_path': '/songs/135334',
#      'artist_names': 'Metric',
#      'full_title': 'Gold Guns Girls by\xa0Metric',
#      'header_image_thumbnail_url': 'https://images.rapgenius.com/0d5a5b2854a7fed74cd8a605e8a91f49.300x298x1.jpg',
#      'header_image_url': 'https://images.rapgenius.com/0d5a5b2854a7fed74cd8a605e8a91f49.600x595x1.jpg',
#      'id': 135334,
#      'lyrics_owner_id': 68632,
#      'lyrics_state': 'complete',
#      'path': '/Metric-gold-guns-girls-lyrics',
#      'pyongs_count': 8,
#      'relationships_index_url': 'https://genius.com/Metric-gold-guns-girls-sample',
#      'release_date_components': {'year': 2009, 'month': 12, 'day': 1},
#      'release_date_for_display': 'December 1, 2009',
#      'release_date_with_abbreviated_month_for_display': 'Dec. 1, 2009',
#      'song_art_image_thumbnail_url': 'https://images.rapgenius.com/0d5a5b2854a7fed74cd8a605e8a91f49.300x298x1.jpg',
#      'song_art_image_url': 'https://images.rapgenius.com/0d5a5b2854a7fed74cd8a605e8a91f49.600x595x1.jpg',
#      'stats': {'unreviewed_annotations': 3, 'hot': False, 'pageviews': 31007},
#      'title': 'Gold Guns Girls',
#      'title_with_featured': 'Gold Guns Girls',
#      'url': 'https://genius.com/Metric-gold-guns-girls-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/17675',
#       'header_image_url': 'https://images.genius.com/109f36066e74d2fd7af65356fcc5f9c0.1000x667x1.jpg',
#       'id': 17675,
#       'image_url': 'https://images.genius.com/c0c4c6f96a97629323551f663ab2f726.667x667x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Metric',
#       'url': 'https://genius.com/artists/Metric'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 2,
#      'api_path': '/songs/3189782',
#      'artist_names': 'Metrickz',
#      'full_title': 'Footprints by\xa0Metrickz',
#      'header_image_thumbnail_url': 'https://images.genius.com/9d8f940d9bd935f51ada9b2b6d7685bd.300x300x1.png',
#      'header_image_url': 'https://images.genius.com/9d8f940d9bd935f51ada9b2b6d7685bd.1000x1000x1.png',
#      'id': 3189782,
#      'lyrics_owner_id': 2171344,
#      'lyrics_state': 'complete',
#      'path': '/Metrickz-footprints-lyrics',
#      'pyongs_count': None,
#      'relationships_index_url': 'https://genius.com/Metrickz-footprints-sample',
#      'release_date_components': {'year': 2017, 'month': 8, 'day': 17},
#      'release_date_for_display': 'August 17, 2017',
#      'release_date_with_abbreviated_month_for_display': 'Aug. 17, 2017',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/9d8f940d9bd935f51ada9b2b6d7685bd.300x300x1.png',
#      'song_art_image_url': 'https://images.genius.com/9d8f940d9bd935f51ada9b2b6d7685bd.1000x1000x1.png',
#      'stats': {'unreviewed_annotations': 0, 'hot': False, 'pageviews': 29876},
#      'title': 'Footprints',
#      'title_with_featured': 'Footprints',
#      'url': 'https://genius.com/Metrickz-footprints-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/20541',
#       'header_image_url': 'https://images.genius.com/d9e65e10bc52a37e922548a98ccf9b8c.1000x400x1.jpg',
#       'id': 20541,
#       'image_url': 'https://images.genius.com/77e38dc764ca197b3105ab0c1270c89a.1000x1000x1.png',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Metrickz',
#       'url': 'https://genius.com/artists/Metrickz'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 10,
#      'api_path': '/songs/224647',
#      'artist_names': 'Metrickz',
#      'full_title': 'Ultraviolett by\xa0Metrickz',
#      'header_image_thumbnail_url': 'https://images.genius.com/07d676459699997d2de0be7e515f3451.300x300x1.png',
#      'header_image_url': 'https://images.genius.com/07d676459699997d2de0be7e515f3451.1000x1000x1.png',
#      'id': 224647,
#      'lyrics_owner_id': 102923,
#      'lyrics_state': 'complete',
#      'path': '/Metrickz-ultraviolett-lyrics',
#      'pyongs_count': 3,
#      'relationships_index_url': 'https://genius.com/Metrickz-ultraviolett-sample',
#      'release_date_components': {'year': 2013, 'month': 9, 'day': 22},
#      'release_date_for_display': 'September 22, 2013',
#      'release_date_with_abbreviated_month_for_display': 'Sep. 22, 2013',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/07d676459699997d2de0be7e515f3451.300x300x1.png',
#      'song_art_image_url': 'https://images.genius.com/07d676459699997d2de0be7e515f3451.1000x1000x1.png',
#      'stats': {'unreviewed_annotations': 0, 'hot': False, 'pageviews': 28673},
#      'title': 'Ultraviolett',
#      'title_with_featured': 'Ultraviolett',
#      'url': 'https://genius.com/Metrickz-ultraviolett-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/20541',
#       'header_image_url': 'https://images.genius.com/d9e65e10bc52a37e922548a98ccf9b8c.1000x400x1.jpg',
#       'id': 20541,
#       'image_url': 'https://images.genius.com/77e38dc764ca197b3105ab0c1270c89a.1000x1000x1.png',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Metrickz',
#       'url': 'https://genius.com/artists/Metrickz'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 2,
#      'api_path': '/songs/2356805',
#      'artist_names': 'Metrickz',
#      'full_title': 'Nicht wie Du by\xa0Metrickz',
#      'header_image_thumbnail_url': 'https://images.rapgenius.com/d07e8a3c3615c6b7a8ec2e8e8c42500b.300x111x1.png',
#      'header_image_url': 'https://images.rapgenius.com/d07e8a3c3615c6b7a8ec2e8e8c42500b.851x315x1.png',
#      'id': 2356805,
#      'lyrics_owner_id': 2280617,
#      'lyrics_state': 'complete',
#      'path': '/Metrickz-nicht-wie-du-lyrics',
#      'pyongs_count': 1,
#      'relationships_index_url': 'https://genius.com/Metrickz-nicht-wie-du-sample',
#      'release_date_components': {'year': 2015, 'month': 11, 'day': 8},
#      'release_date_for_display': 'November 8, 2015',
#      'release_date_with_abbreviated_month_for_display': 'Nov. 8, 2015',
#      'song_art_image_thumbnail_url': 'https://images.rapgenius.com/ba0b7742b098fd39cd328cda68e62347.300x300x1.jpg',
#      'song_art_image_url': 'https://images.rapgenius.com/ba0b7742b098fd39cd328cda68e62347.960x960x1.jpg',
#      'stats': {'unreviewed_annotations': 1, 'hot': False, 'pageviews': 28332},
#      'title': 'Nicht wie Du',
#      'title_with_featured': 'Nicht wie Du',
#      'url': 'https://genius.com/Metrickz-nicht-wie-du-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/20541',
#       'header_image_url': 'https://images.genius.com/d9e65e10bc52a37e922548a98ccf9b8c.1000x400x1.jpg',
#       'id': 20541,
#       'image_url': 'https://images.genius.com/77e38dc764ca197b3105ab0c1270c89a.1000x1000x1.png',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Metrickz',
#       'url': 'https://genius.com/artists/Metrickz'}}}]}}

# %% [markdown]
# Turns out the [1] to try and skip possible collaborations overshot Metric, but we can use [0] to get their artist endpoint.
#
# For simplicity I'm just manually copying their artist endpoint into the dictionary.

# %%
artist_endpoints['Metric'] = '/artists/17675'
artist_endpoints['Metric']
# Out:
# '/artists/17675'

# %% [markdown]
# ## Spotify API for album information and tracklists
# Lyrics Genius API doesn't want me to get albums by artist.....so we will try Spotify's API

# %%
def get_spotify_token():
    auth_string = spotifyclientid + ":" + spotifyclientsecret
    auth_bytes = auth_string.encode('utf-8')
    auth_base64 = str(base64.b64encode(auth_bytes), 'utf-8')
    url = 'https://accounts.spotify.com/api/token'
    headers = {
        'Authorization':'Basic ' + auth_base64,
        'Content-Type':'application/x-www-form-urlencoded'
    }
    data = {'grant_type':'client_credentials'}
    result = requests.post(url, headers=headers, data=data)
    json_result = json.loads(result.content)
    token = json_result['access_token']
    return token

def get_spotify_auth_header(token):
    return {'Authorization':'Bearer ' + token}

def search_for_artist(token, artist_name):
    url = 'https://api.spotify.com/v1/search'
    headers = get_spotify_auth_header(token)
    query = f'?q={artist_name}&type=artist&limit=1'
    query_url = url + query
    result = requests.get(query_url, headers=headers)
    json_result = json.loads(result.content)['artists']['items']
    if len(json_result) == 0:
        print(f'Could not find artist with name {artist_name}')
        return None
    return {'artist_name':json_result[0]['name'],
            'artist_id':json_result[0]['id'],
            'followers':json_result[0]['followers']['total'],
            'genres':json_result[0]['genres'],
            'popularity':json_result[0]['popularity']
    }

def get_albums_by_artist(token, artist_id):
    url = f'https://api.spotify.com/v1/artists/{artist_id}/albums?include_groups=album&market=US'
    headers = get_spotify_auth_header(token)
    result = requests.get(url, headers=headers)
    album_list = json.loads(result.content)['items']
    return album_list

def get_tracklist_by_album(token, album_id):
    url = f'https://api.spotify.com/v1/albums/{album_id}/?market=US'
    headers = get_spotify_auth_header(token)
    result = requests.get(url, headers=headers)
    track_list = json.loads(result.content)
    return track_list

def get_audio_features_by_song(token, song_id):
    url = f'https://api.spotify.com/v1/audio-features/{song_id}'
    headers = get_spotify_auth_header(token)
    result = requests.get(url, headers=headers)
    audio_features = json.loads(result.content)
    return audio_features

def parse_album_list(album_list):
    album_dict = {}
    for album in album_list:
        album_name = album['name']
        album_dict[album_name] = {'album_id':album['id'],
                                  'release_date':album['release_date'],
                                  'total_tracks':album['total_tracks'],
                                  'tracklist':{}
        }
    return album_dict

# Since we get to the song level here, we might as well get the audio information here too
def parse_tracklist(token, track_list):
    tracklist_dict = {}
    album_label = track_list['label']
    for track in track_list['tracks']['items']:
        track_name = track['name']
        track_id = track['id']
        audio_info = get_audio_features_by_song(token, track_id)
        tracklist_dict[track_name] = {'track_id':track['id'],
                                      'disc_number':track['disc_number'],
                                      'duration_ms':track['duration_ms'],
                                      'track_number':track['track_number'],
                                      'audio_information':audio_info}
    return album_label, tracklist_dict

# %%
spotify_token = get_spotify_token()

# %%
search_for_artist(spotify_token, 'St. Vincent')
# Out:
# {'artist_name': 'St. Vincent',
#  'artist_id': '7bcbShaqKdcyjnmv4Ix8j6',
#  'followers': 832341,
#  'genres': ['art pop',
#   'etherpop',
#   'indie rock',
#   'indietronica',
#   'metropopolis',
#   'neo-synthpop'],
#  'popularity': 62}

# %% [markdown]
# ### Generate Artist Data Dictionary
# We want to store artist metadata, albums, album info, tracklist, songs, and lyrics

# %%
spotify_artist_data = {}
for artist in artist_list:
    artist_data = search_for_artist(spotify_token, artist)
    spotify_artist_data[artist] = {'Metadata':artist_data}

# %%
spotify_artist_data.keys()
# Out:
# dict_keys(['St. Vincent', 'LCD Soundsystem', 'Dirty Projectors', 'Ava Luna', 'Caroline Polachek', 'Mr. Twin Sister', 'The Marias', 'Pure Bathing Culture', 'Cults', 'The National', 'Ethel Cain', 'CHVRCHES', 'Big Thief', 'Holychild', 'Yeah Yeah Yeahs', 'MGMT', 'Radiohead', 'Metric', 'Broken Social Scene'])

# %%
spotify_artist_data['St. Vincent']['Metadata']['artist_id']
# Out:
# '7bcbShaqKdcyjnmv4Ix8j6'

# %%
spotify_artist_data
# Out:
# {'St. Vincent': {'Metadata': {'artist_name': 'St. Vincent',
#    'artist_id': '7bcbShaqKdcyjnmv4Ix8j6',
#    'followers': 832341,
#    'genres': ['art pop',
#     'etherpop',
#     'indie rock',
#     'indietronica',
#     'metropopolis',
#     'neo-synthpop'],
#    'popularity': 62}},
#  'LCD Soundsystem': {'Metadata': {'artist_name': 'LCD Soundsystem',
#    'artist_id': '066X20Nz7iquqkkCW6Jxy6',
#    'followers': 1080622,
#    'genres': ['alternative dance',
#     'alternative rock',
#     'art pop',
#     'dance rock',
#     'dance-punk',
#     'electronic rock',
#     'electronica',
#     'indie rock',
#     'indietronica',
#     'neo-synthpop',
#     'new rave'],
#    'popularity': 59}},
#  'Dirty Projectors': {'Metadata': {'artist_name': 'Dirty Projectors',
#    'artist_id': '5VF0YkVLeVD4ytyiyVSIiF',
#    'followers': 252286,
#    'genres': ['art pop',
#     'brooklyn indie',
#     'indie rock',
#     'indietronica',
#     'noise pop'],
#    'popularity': 40}},
#  'Ava Luna': {'Metadata': {'artist_name': 'Ava Luna',
#    'artist_id': '7xkkeemZnfafRwrWEtlyaN',
#    'followers': 8269,
#    'genres': ['brooklyn indie'],
#    'popularity': 9}},
#  'Caroline Polachek': {'Metadata': {'artist_name': 'Caroline Polachek',
#    'artist_id': '4Ge8xMJNwt6EEXOzVXju9a',
#    'followers': 475978,
#    'genres': ['art pop', 'escape room', 'indie pop', 'indietronica'],
#    'popularity': 63}},
#  'Mr. Twin Sister': {'Metadata': {'artist_name': 'Mr Twin Sister',
#    'artist_id': '5ltJZgIW3OkY5WvuzX5MYz',
#    'followers': 98766,
#    'genres': ['chillwave'],
#    'popularity': 46}},
#  'The Marias': {'Metadata': {'artist_name': 'The Marías',
#    'artist_id': '2sSGPbdZJkaSE2AbcGOACx',
#    'followers': 1184376,
#    'genres': ['bedroom pop', 'la indie'],
#    'popularity': 70}},
#  'Pure Bathing Culture': {'Metadata': {'artist_name': 'Pure Bathing Culture',
#    'artist_id': '4WrK3qZXMjfwl0dQj09QSD',
#    'followers': 19207,
#    'genres': ['chillwave', 'shiver pop'],
#    'popularity': 25}},
#  'Cults': {'Metadata': {'artist_name': 'Cults',
#    'artist_id': '3Oim8XBPbznAa8Jj8QzNc8',
#    'followers': 847467,
#    'genres': ['experimental pop', 'indie surf', 'pov: indie'],
#    'popularity': 69}},
#  'The National': {'Metadata': {'artist_name': 'The National',
#    'artist_id': '2cCUtGK9sDU2EoElnk0GNB',
#    'followers': 1583389,
#    'genres': ['chamber pop',
#     'indie folk',
#     'indie rock',
#     'indietronica',
#     'irish rock',
#     'modern rock'],
#    'popularity': 67}},
#  'Ethel Cain': {'Metadata': {'artist_name': 'Ethel Cain',
#    'artist_id': '0avMDS4HyoCEP6RqZJWpY2',
#    'followers': 474816,
#    'genres': ['countrygaze', 'indie pop', 'modern dream pop'],
#    'popularity': 63}},
#  'CHVRCHES': {'Metadata': {'artist_name': 'CHVRCHES',
#    'artist_id': '3CjlHNtplJyTf9npxaPl5w',
#    'followers': 1375970,
#    'genres': ['indietronica', 'metropopolis', 'neo-synthpop', 'shimmer pop'],
#    'popularity': 62}},
#  'Big Thief': {'Metadata': {'artist_name': 'Big Thief',
#    'artist_id': '5QdyldG4Fl4TPiOIeMNpBZ',
#    'followers': 745342,
#    'genres': ['art pop',
#     'brooklyn indie',
#     'chamber pop',
#     'countrygaze',
#     'indie pop',
#     'indie rock',
#     'small room'],
#    'popularity': 66}},
#  'Holychild': {'Metadata': {'artist_name': 'HOLYCHILD',
#    'artist_id': '4itksv8jgpEcvRvZ7lDalQ',
#    'followers': 51898,
#    'genres': ['indie poptimism', 'la indie'],
#    'popularity': 37}},
#  'Yeah Yeah Yeahs': {'Metadata': {'artist_name': 'Yeah Yeah Yeahs',
#    'artist_id': '3TNt4aUIxgfy9aoaft5Jj2',
#    'followers': 1275647,
#    'genres': ['alternative dance',
#     'alternative rock',
#     'art pop',
#     'dance-punk',
#     'garage rock',
#     'indie rock',
#     'modern rock',
#     'neo-synthpop',
#     'new rave'],
#    'popularity': 64}},
#  'MGMT': {'Metadata': {'artist_name': 'MGMT',
#    'artist_id': '0SwO7SWeDHJijQ3XNS7xEE',
#    'followers': 3012018,
#    'genres': ['alternative rock',
#     'indie rock',
#     'indietronica',
#     'modern rock',
#     'rock'],
#    'popularity': 75}},
#  'Radiohead': {'Metadata': {'artist_name': 'Radiohead',
#    'artist_id': '4Z8W4fKeB5YxbusRsdQVPb',
#    'followers': 9514465,
#    'genres': ['alternative rock',
#     'art rock',
#     'melancholia',
#     'oxford indie',
#     'permanent wave',
#     'rock'],
#    'popularity': 81}},
#  'Metric': {'Metadata': {'artist_name': 'Metric',
#    'artist_id': '1rCIEwPp5OnXW0ornlSsRl',
#    'followers': 804601,
#    'genres': ['canadian indie',
#     'canadian rock',
#     'indie rock',
#     'indietronica',
#     'metropopolis',
#     'neo-synthpop'],
#    'popularity': 62}},
#  'Broken Social Scene': {'Metadata': {'artist_name': 'Broken Social Scene',
#    'artist_id': '7lOJ7WXyopaxri0dbOiZkd',
#    'followers': 359643,
#    'genres': ['alternative rock',
#     'baroque pop',
#     'canadian indie',
#     'canadian indie rock',
#     'canadian rock',
#     'indie rock',
#     'noise pop'],
#    'popularity': 47}}}

# %% [markdown]
# ### Get Albums by Artist

# %%
for artist in spotify_artist_data:
    artist_id = spotify_artist_data[artist]['Metadata']['artist_id']
    spotify_artist_data[artist]['Albums'] = parse_album_list(get_albums_by_artist(spotify_token, artist_id))

# %%
spotify_artist_data['Dirty Projectors']['Albums']
# Out:
# {'Mount Wittenberg Orca (Expanded Edition)': {'album_id': '14xINYt1omt6jlxv8AFbly',
#   'release_date': '2023-06-16',
#   'total_tracks': 27,
#   'tracklist': {}},
#  '5EPs': {'album_id': '7u0QlPnsqX06KfavgPeSET',
#   'release_date': '2020-11-20',
#   'total_tracks': 20,
#   'tracklist': {}},
#  'Sing The Melody': {'album_id': '48gORfOPT5iEm9eooBAQiv',
#   'release_date': '2019-12-10',
#   'total_tracks': 8,
#   'tracklist': {}},
#  'Lamp Lit Prose': {'album_id': '03CZTX0lcoZGy71rOHnDxn',
#   'release_date': '2018-07-13',
#   'total_tracks': 10,
#   'tracklist': {}},
#  'Dirty Projectors': {'album_id': '6HA2YKWabsGi6XWkhWoZuA',
#   'release_date': '2017-02-21',
#   'total_tracks': 9,
#   'tracklist': {}},
#  'Swing Lo Magellan': {'album_id': '5zQgu9qi6mK8KuleuzM22C',
#   'release_date': '2012-07-10',
#   'total_tracks': 12,
#   'tracklist': {}},
#  'Mount Wittenberg Orca': {'album_id': '1C9sn8azB8qNZyPSCgkNJz',
#   'release_date': '2011-10-25',
#   'total_tracks': 7,
#   'tracklist': {}},
#  'Bitte Orca (Expanded Edition)': {'album_id': '2MWOU3Lgu3bUZg9QeqxQMr',
#   'release_date': '2010-09-27',
#   'total_tracks': 20,
#   'tracklist': {}},
#  'Bitte Orca': {'album_id': '2Geg4mwE8z9DO5BSSUoMKz',
#   'release_date': '2009-06-03',
#   'total_tracks': 9,
#   'tracklist': {}},
#  'Rise Above': {'album_id': '47M92OOuXeVTaBymQmp3bo',
#   'release_date': '2007-09-11',
#   'total_tracks': 11,
#   'tracklist': {}},
#  'The Getty Address': {'album_id': '3SMGmEqgQHZql6Bk2pOTUZ',
#   'release_date': '2005-04-05',
#   'total_tracks': 13,
#   'tracklist': {}},
#  "Slaves' Graves and Ballads": {'album_id': '0qV69nfC11r7LlfZc27tTL',
#   'release_date': '2004-08-06',
#   'total_tracks': 14,
#   'tracklist': {}},
#  'The Glad Fact': {'album_id': '6qseEttDbxvHdJWKovpe0A',
#   'release_date': '2003-04-11',
#   'total_tracks': 15,
#   'tracklist': {}},
#  'Morning Better Last!': {'album_id': '0BxOpqwW1aBWAovjUeSi5w',
#   'release_date': '2003',
#   'total_tracks': 23,
#   'tracklist': {}}}

# %% [markdown]
# ## Get tracklist by album

# %%
for artist in spotify_artist_data:
    for album in spotify_artist_data[artist]['Albums']:
        album_id = spotify_artist_data[artist]['Albums'][album]['album_id']
        album_tracklist = get_tracklist_by_album(spotify_token, album_id)
        spotify_artist_data[artist]['Albums'][album]['label'], spotify_artist_data[artist]['Albums'][album]['tracklist'] = parse_tracklist(spotify_token, album_tracklist)

# %%
spotify_artist_data['LCD Soundsystem']['Albums']['american dream']
# Out:
# {'album_id': '0hdimlCTCms7otJCX9OvqM',
#  'release_date': '2017-10-06',
#  'total_tracks': 11,
#  'tracklist': {'oh baby': {'track_id': '1Y5EqnpZLLoAp4RQQTr10O',
#    'disc_number': 1,
#    'duration_ms': 349693,
#    'track_number': 1,
#    'audio_information': {'danceability': 0.581,
#     'energy': 0.623,
#     'key': 5,
#     'loudness': -12.005,
#     'mode': 1,
#     'speechiness': 0.0351,
#     'acousticness': 0.0196,
#     'instrumentalness': 0.626,
#     'liveness': 0.653,
#     'valence': 0.78,
#     'tempo': 169.443,
#     'type': 'audio_features',
#     'id': '1Y5EqnpZLLoAp4RQQTr10O',
#     'uri': 'spotify:track:1Y5EqnpZLLoAp4RQQTr10O',
#     'track_href': 'https://api.spotify.com/v1/tracks/1Y5EqnpZLLoAp4RQQTr10O',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1Y5EqnpZLLoAp4RQQTr10O',
#     'duration_ms': 349693,
#     'time_signature': 4}},
#   'other voices': {'track_id': '0nTW4n6goPkpnoaBBeSjXm',
#    'disc_number': 1,
#    'duration_ms': 403346,
#    'track_number': 2,
#    'audio_information': {'danceability': 0.722,
#     'energy': 0.684,
#     'key': 11,
#     'loudness': -10.322,
#     'mode': 0,
#     'speechiness': 0.0577,
#     'acousticness': 0.00198,
#     'instrumentalness': 0.629,
#     'liveness': 0.0759,
#     'valence': 0.895,
#     'tempo': 124.332,
#     'type': 'audio_features',
#     'id': '0nTW4n6goPkpnoaBBeSjXm',
#     'uri': 'spotify:track:0nTW4n6goPkpnoaBBeSjXm',
#     'track_href': 'https://api.spotify.com/v1/tracks/0nTW4n6goPkpnoaBBeSjXm',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0nTW4n6goPkpnoaBBeSjXm',
#     'duration_ms': 403347,
#     'time_signature': 4}},
#   'i used to': {'track_id': '404ZIfgGYd8VnwUn0HA1Pd',
#    'disc_number': 1,
#    'duration_ms': 332386,
#    'track_number': 3,
#    'audio_information': {'danceability': 0.625,
#     'energy': 0.742,
#     'key': 11,
#     'loudness': -7.913,
#     'mode': 0,
#     'speechiness': 0.0285,
#     'acousticness': 0.00598,
#     'instrumentalness': 0.00288,
#     'liveness': 0.0921,
#     'valence': 0.508,
#     'tempo': 112.639,
#     'type': 'audio_features',
#     'id': '404ZIfgGYd8VnwUn0HA1Pd',
#     'uri': 'spotify:track:404ZIfgGYd8VnwUn0HA1Pd',
#     'track_href': 'https://api.spotify.com/v1/tracks/404ZIfgGYd8VnwUn0HA1Pd',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/404ZIfgGYd8VnwUn0HA1Pd',
#     'duration_ms': 332387,
#     'time_signature': 4}},
#   'change yr mind': {'track_id': '0My2pMmVxevwrGyd1CR8u2',
#    'disc_number': 1,
#    'duration_ms': 297546,
#    'track_number': 4,
#    'audio_information': {'danceability': 0.762,
#     'energy': 0.849,
#     'key': 10,
#     'loudness': -8.468,
#     'mode': 0,
#     'speechiness': 0.0561,
#     'acousticness': 0.0168,
#     'instrumentalness': 0.514,
#     'liveness': 0.087,
#     'valence': 0.756,
#     'tempo': 105.008,
#     'type': 'audio_features',
#     'id': '0My2pMmVxevwrGyd1CR8u2',
#     'uri': 'spotify:track:0My2pMmVxevwrGyd1CR8u2',
#     'track_href': 'https://api.spotify.com/v1/tracks/0My2pMmVxevwrGyd1CR8u2',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0My2pMmVxevwrGyd1CR8u2',
#     'duration_ms': 297547,
#     'time_signature': 4}},
#   'how do you sleep?': {'track_id': '3ETW8l9FuVFpPHUSTyZDK4',
#    'disc_number': 1,
#    'duration_ms': 552240,
#    'track_number': 5,
#    'audio_information': {'danceability': 0.64,
#     'energy': 0.566,
#     'key': 0,
#     'loudness': -9.059,
#     'mode': 1,
#     'speechiness': 0.0325,
#     'acousticness': 0.00428,
#     'instrumentalness': 0.101,
#     'liveness': 0.15,
#     'valence': 0.417,
#     'tempo': 105.926,
#     'type': 'audio_features',
#     'id': '3ETW8l9FuVFpPHUSTyZDK4',
#     'uri': 'spotify:track:3ETW8l9FuVFpPHUSTyZDK4',
#     'track_href': 'https://api.spotify.com/v1/tracks/3ETW8l9FuVFpPHUSTyZDK4',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ETW8l9FuVFpPHUSTyZDK4',
#     'duration_ms': 552240,
#     'time_signature': 4}},
#   'tonite': {'track_id': '2iQov70C2Cs6KCu8Dk8wW1',
#    'disc_number': 1,
#    'duration_ms': 347346,
#    'track_number': 6,
#    'audio_information': {'danceability': 0.766,
#     'energy': 0.787,
#     'key': 2,
#     'loudness': -8.284,
#     'mode': 1,
#     'speechiness': 0.0565,
#     'acousticness': 0.0692,
#     'instrumentalness': 0.00466,
#     'liveness': 0.434,
#     'valence': 0.839,
#     'tempo': 121.105,
#     'type': 'audio_features',
#     'id': '2iQov70C2Cs6KCu8Dk8wW1',
#     'uri': 'spotify:track:2iQov70C2Cs6KCu8Dk8wW1',
#     'track_href': 'https://api.spotify.com/v1/tracks/2iQov70C2Cs6KCu8Dk8wW1',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2iQov70C2Cs6KCu8Dk8wW1',
#     'duration_ms': 347347,
#     'time_signature': 4}},
#   'call the police': {'track_id': '5rhgZSkr7P8ZNx7OxBbdOw',
#    'disc_number': 1,
#    'duration_ms': 418773,
#    'track_number': 7,
#    'audio_information': {'danceability': 0.38,
#     'energy': 0.727,
#     'key': 2,
#     'loudness': -6.477,
#     'mode': 1,
#     'speechiness': 0.0435,
#     'acousticness': 9.25e-05,
#     'instrumentalness': 0.00488,
#     'liveness': 0.0744,
#     'valence': 0.34,
#     'tempo': 151.012,
#     'type': 'audio_features',
#     'id': '5rhgZSkr7P8ZNx7OxBbdOw',
#     'uri': 'spotify:track:5rhgZSkr7P8ZNx7OxBbdOw',
#     'track_href': 'https://api.spotify.com/v1/tracks/5rhgZSkr7P8ZNx7OxBbdOw',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5rhgZSkr7P8ZNx7OxBbdOw',
#     'duration_ms': 418773,
#     'time_signature': 4}},
#   'american dream': {'track_id': '37sZCRrGMdDsYg7QqqvdnR',
#    'disc_number': 1,
#    'duration_ms': 366786,
#    'track_number': 8,
#    'audio_information': {'danceability': 0.291,
#     'energy': 0.538,
#     'key': 0,
#     'loudness': -8.37,
#     'mode': 1,
#     'speechiness': 0.0314,
#     'acousticness': 0.0515,
#     'instrumentalness': 0.00401,
#     'liveness': 0.207,
#     'valence': 0.198,
#     'tempo': 202.026,
#     'type': 'audio_features',
#     'id': '37sZCRrGMdDsYg7QqqvdnR',
#     'uri': 'spotify:track:37sZCRrGMdDsYg7QqqvdnR',
#     'track_href': 'https://api.spotify.com/v1/tracks/37sZCRrGMdDsYg7QqqvdnR',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/37sZCRrGMdDsYg7QqqvdnR',
#     'duration_ms': 366787,
#     'time_signature': 3}},
#   'emotional haircut': {'track_id': '0cxDKzFxhhYj2EYAxKsHwB',
#    'disc_number': 1,
#    'duration_ms': 329213,
#    'track_number': 9,
#    'audio_information': {'danceability': 0.626,
#     'energy': 0.949,
#     'key': 9,
#     'loudness': -7.061,
#     'mode': 1,
#     'speechiness': 0.113,
#     'acousticness': 0.00342,
#     'instrumentalness': 0.642,
#     'liveness': 0.104,
#     'valence': 0.489,
#     'tempo': 150.503,
#     'type': 'audio_features',
#     'id': '0cxDKzFxhhYj2EYAxKsHwB',
#     'uri': 'spotify:track:0cxDKzFxhhYj2EYAxKsHwB',
#     'track_href': 'https://api.spotify.com/v1/tracks/0cxDKzFxhhYj2EYAxKsHwB',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0cxDKzFxhhYj2EYAxKsHwB',
#     'duration_ms': 329213,
#     'time_signature': 4}},
#   'black screen': {'track_id': '6kKXowSTq8uKZhdFPdG9BS',
#    'disc_number': 1,
#    'duration_ms': 728360,
#    'track_number': 10,
#    'audio_information': {'danceability': 0.584,
#     'energy': 0.433,
#     'key': 7,
#     'loudness': -14.59,
#     'mode': 1,
#     'speechiness': 0.0253,
#     'acousticness': 0.321,
#     'instrumentalness': 0.923,
#     'liveness': 0.0912,
#     'valence': 0.0721,
#     'tempo': 100.01,
#     'type': 'audio_features',
#     'id': '6kKXowSTq8uKZhdFPdG9BS',
#     'uri': 'spotify:track:6kKXowSTq8uKZhdFPdG9BS',
#     'track_href': 'https://api.spotify.com/v1/tracks/6kKXowSTq8uKZhdFPdG9BS',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6kKXowSTq8uKZhdFPdG9BS',
#     'duration_ms': 728360,
#     'time_signature': 4}},
#   'pulse (v.1)': {'track_id': '3HEHSCGLO452rRpPkHQkYy',
#    'disc_number': 1,
#    'duration_ms': 822640,
#    'track_number': 11,
#    'audio_information': {'danceability': 0.709,
#     'energy': 0.687,
#     'key': 1,
#     'loudness': -12.527,
#     'mode': 1,
#     'speechiness': 0.0394,
#     'acousticness': 0.457,
#     'instrumentalness': 0.837,
#     'liveness': 0.0951,
#     'valence': 0.852,
#     'tempo': 112.184,
#     'type': 'audio_features',
#     'id': '3HEHSCGLO452rRpPkHQkYy',
#     'uri': 'spotify:track:3HEHSCGLO452rRpPkHQkYy',
#     'track_href': 'https://api.spotify.com/v1/tracks/3HEHSCGLO452rRpPkHQkYy',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3HEHSCGLO452rRpPkHQkYy',
#     'duration_ms': 822640,
#     'time_signature': 1}}},
#  'label': 'DFA Records/Columbia'}

# %% [markdown]
# ## Append lyrics artist endpoint for ease of access

# %%
for sp_artist in spotify_artist_data:
    for lg_artist in artist_endpoints:
        if sp_artist == lg_artist:
            spotify_artist_data[sp_artist]['Metadata']['lg_endpoint'] = artist_endpoints[lg_artist]

# %%
spotify_artist_data['Metric']
# Out:
# {'Metadata': {'artist_name': 'Metric',
#   'artist_id': '1rCIEwPp5OnXW0ornlSsRl',
#   'followers': 804601,
#   'genres': ['canadian indie',
#    'canadian rock',
#    'indie rock',
#    'indietronica',
#    'metropopolis',
#    'neo-synthpop'],
#   'popularity': 62,
#   'lg_endpoint': '/artists/17675'},
#  'Albums': {'Formentera II': {'album_id': '4SH7eiRuT8MdrLnL52gB1O',
#    'release_date': '2023-10-13',
#    'total_tracks': 9,
#    'tracklist': {'Detour Up': {'track_id': '0urzesdU9xIlWnvUaRBDaV',
#      'disc_number': 1,
#      'duration_ms': 218416,
#      'track_number': 1,
#      'audio_information': {'danceability': 0.682,
#       'energy': 0.738,
#       'key': 9,
#       'loudness': -6.394,
#       'mode': 0,
#       'speechiness': 0.0317,
#       'acousticness': 0.00393,
#       'instrumentalness': 0.00495,
#       'liveness': 0.562,
#       'valence': 0.584,
#       'tempo': 116.906,
#       'type': 'audio_features',
#       'id': '0urzesdU9xIlWnvUaRBDaV',
#       'uri': 'spotify:track:0urzesdU9xIlWnvUaRBDaV',
#       'track_href': 'https://api.spotify.com/v1/tracks/0urzesdU9xIlWnvUaRBDaV',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0urzesdU9xIlWnvUaRBDaV',
#       'duration_ms': 218416,
#       'time_signature': 4}},
#     'Just The Once': {'track_id': '02PWMXbnLbqIODveV4db4t',
#      'disc_number': 1,
#      'duration_ms': 204899,
#      'track_number': 2,
#      'audio_information': {'danceability': 0.688,
#       'energy': 0.783,
#       'key': 9,
#       'loudness': -5.3,
#       'mode': 1,
#       'speechiness': 0.0327,
#       'acousticness': 0.00107,
#       'instrumentalness': 0.385,
#       'liveness': 0.136,
#       'valence': 0.865,
#       'tempo': 119.003,
#       'type': 'audio_features',
#       'id': '02PWMXbnLbqIODveV4db4t',
#       'uri': 'spotify:track:02PWMXbnLbqIODveV4db4t',
#       'track_href': 'https://api.spotify.com/v1/tracks/02PWMXbnLbqIODveV4db4t',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/02PWMXbnLbqIODveV4db4t',
#       'duration_ms': 204900,
#       'time_signature': 4}},
#     'Stone Window': {'track_id': '5XXd2JyyZ0ILyd4gKtYHDu',
#      'disc_number': 1,
#      'duration_ms': 240831,
#      'track_number': 3,
#      'audio_information': {'danceability': 0.62,
#       'energy': 0.807,
#       'key': 4,
#       'loudness': -5.638,
#       'mode': 0,
#       'speechiness': 0.0424,
#       'acousticness': 0.0116,
#       'instrumentalness': 0.0811,
#       'liveness': 0.104,
#       'valence': 0.471,
#       'tempo': 126.613,
#       'type': 'audio_features',
#       'id': '5XXd2JyyZ0ILyd4gKtYHDu',
#       'uri': 'spotify:track:5XXd2JyyZ0ILyd4gKtYHDu',
#       'track_href': 'https://api.spotify.com/v1/tracks/5XXd2JyyZ0ILyd4gKtYHDu',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5XXd2JyyZ0ILyd4gKtYHDu',
#       'duration_ms': 240832,
#       'time_signature': 4}},
#     'Days Of Oblivion': {'track_id': '2p83KMWc8xidIJ0RwXsz25',
#      'disc_number': 1,
#      'duration_ms': 359184,
#      'track_number': 4,
#      'audio_information': {'danceability': 0.505,
#       'energy': 0.711,
#       'key': 6,
#       'loudness': -5.518,
#       'mode': 0,
#       'speechiness': 0.0278,
#       'acousticness': 0.011,
#       'instrumentalness': 0.0189,
#       'liveness': 0.307,
#       'valence': 0.441,
#       'tempo': 143.96,
#       'type': 'audio_features',
#       'id': '2p83KMWc8xidIJ0RwXsz25',
#       'uri': 'spotify:track:2p83KMWc8xidIJ0RwXsz25',
#       'track_href': 'https://api.spotify.com/v1/tracks/2p83KMWc8xidIJ0RwXsz25',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2p83KMWc8xidIJ0RwXsz25',
#       'duration_ms': 359185,
#       'time_signature': 4}},
#     'Who Would You Be For Me': {'track_id': '56QBBRoTZg29J9E6MoiWgg',
#      'disc_number': 1,
#      'duration_ms': 301333,
#      'track_number': 5,
#      'audio_information': {'danceability': 0.547,
#       'energy': 0.573,
#       'key': 11,
#       'loudness': -6.732,
#       'mode': 1,
#       'speechiness': 0.0266,
#       'acousticness': 0.0457,
#       'instrumentalness': 0.0929,
#       'liveness': 0.0827,
#       'valence': 0.301,
#       'tempo': 135.953,
#       'type': 'audio_features',
#       'id': '56QBBRoTZg29J9E6MoiWgg',
#       'uri': 'spotify:track:56QBBRoTZg29J9E6MoiWgg',
#       'track_href': 'https://api.spotify.com/v1/tracks/56QBBRoTZg29J9E6MoiWgg',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/56QBBRoTZg29J9E6MoiWgg',
#       'duration_ms': 301334,
#       'time_signature': 4}},
#     'Suckers': {'track_id': '7FA4xByztAlNvzZnFKX4si',
#      'disc_number': 1,
#      'duration_ms': 269123,
#      'track_number': 6,
#      'audio_information': {'danceability': 0.35,
#       'energy': 0.838,
#       'key': 7,
#       'loudness': -4.225,
#       'mode': 1,
#       'speechiness': 0.0444,
#       'acousticness': 0.00428,
#       'instrumentalness': 0.0226,
#       'liveness': 0.338,
#       'valence': 0.108,
#       'tempo': 115.005,
#       'type': 'audio_features',
#       'id': '7FA4xByztAlNvzZnFKX4si',
#       'uri': 'spotify:track:7FA4xByztAlNvzZnFKX4si',
#       'track_href': 'https://api.spotify.com/v1/tracks/7FA4xByztAlNvzZnFKX4si',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7FA4xByztAlNvzZnFKX4si',
#       'duration_ms': 269124,
#       'time_signature': 4}},
#     'Nothing Is Perfect': {'track_id': '71Dm4cHETshKNkYAzBy3sP',
#      'disc_number': 1,
#      'duration_ms': 210760,
#      'track_number': 7,
#      'audio_information': {'danceability': 0.554,
#       'energy': 0.46,
#       'key': 5,
#       'loudness': -8.841,
#       'mode': 1,
#       'speechiness': 0.0276,
#       'acousticness': 0.174,
#       'instrumentalness': 7.15e-05,
#       'liveness': 0.0974,
#       'valence': 0.223,
#       'tempo': 139.972,
#       'type': 'audio_features',
#       'id': '71Dm4cHETshKNkYAzBy3sP',
#       'uri': 'spotify:track:71Dm4cHETshKNkYAzBy3sP',
#       'track_href': 'https://api.spotify.com/v1/tracks/71Dm4cHETshKNkYAzBy3sP',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/71Dm4cHETshKNkYAzBy3sP',
#       'duration_ms': 210761,
#       'time_signature': 4}},
#     'Descendants': {'track_id': '5CDfF9IDWUBw6h4OQYkDKM',
#      'disc_number': 1,
#      'duration_ms': 354382,
#      'track_number': 8,
#      'audio_information': {'danceability': 0.493,
#       'energy': 0.63,
#       'key': 2,
#       'loudness': -8.53,
#       'mode': 0,
#       'speechiness': 0.0341,
#       'acousticness': 0.162,
#       'instrumentalness': 0.518,
#       'liveness': 0.106,
#       'valence': 0.287,
#       'tempo': 139.996,
#       'type': 'audio_features',
#       'id': '5CDfF9IDWUBw6h4OQYkDKM',
#       'uri': 'spotify:track:5CDfF9IDWUBw6h4OQYkDKM',
#       'track_href': 'https://api.spotify.com/v1/tracks/5CDfF9IDWUBw6h4OQYkDKM',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5CDfF9IDWUBw6h4OQYkDKM',
#       'duration_ms': 354382,
#       'time_signature': 4}},
#     'Go Ahead And Cry': {'track_id': '1aTqKGkGSTMCHSL1u5gTwU',
#      'disc_number': 1,
#      'duration_ms': 243325,
#      'track_number': 9,
#      'audio_information': {'danceability': 0.465,
#       'energy': 0.745,
#       'key': 10,
#       'loudness': -4.738,
#       'mode': 1,
#       'speechiness': 0.0281,
#       'acousticness': 0.0256,
#       'instrumentalness': 0.000113,
#       'liveness': 0.116,
#       'valence': 0.46,
#       'tempo': 137.102,
#       'type': 'audio_features',
#       'id': '1aTqKGkGSTMCHSL1u5gTwU',
#       'uri': 'spotify:track:1aTqKGkGSTMCHSL1u5gTwU',
#       'track_href': 'https://api.spotify.com/v1/tracks/1aTqKGkGSTMCHSL1u5gTwU',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1aTqKGkGSTMCHSL1u5gTwU',
#       'duration_ms': 243325,
#       'time_signature': 4}}},
#    'label': 'Metric Music International, Inc.'},
#   'Formentera': {'album_id': '1S5vq5vSHCnCJnMljIiuS6',
#    'release_date': '2022-07-08',
#    'total_tracks': 9,
#    'tracklist': {'Doomscroller': {'track_id': '1gvGmBd2bVWefyeVZzuRSn',
#      'disc_number': 1,
#      'duration_ms': 628733,
#      'track_number': 1,
#      'audio_information': {'danceability': 0.389,
#       'energy': 0.6,
#       'key': 2,
#       'loudness': -7.799,
#       'mode': 0,
#       'speechiness': 0.0569,
#       'acousticness': 0.123,
#       'instrumentalness': 0.409,
#       'liveness': 0.0959,
#       'valence': 0.117,
#       'tempo': 127.038,
#       'type': 'audio_features',
#       'id': '1gvGmBd2bVWefyeVZzuRSn',
#       'uri': 'spotify:track:1gvGmBd2bVWefyeVZzuRSn',
#       'track_href': 'https://api.spotify.com/v1/tracks/1gvGmBd2bVWefyeVZzuRSn',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1gvGmBd2bVWefyeVZzuRSn',
#       'duration_ms': 628733,
#       'time_signature': 4}},
#     'All Comes Crashing': {'track_id': '4XRvI0XtqdOGYeC36VkbwA',
#      'disc_number': 1,
#      'duration_ms': 263080,
#      'track_number': 2,
#      'audio_information': {'danceability': 0.7,
#       'energy': 0.686,
#       'key': 7,
#       'loudness': -6.888,
#       'mode': 0,
#       'speechiness': 0.0343,
#       'acousticness': 0.00606,
#       'instrumentalness': 0.000345,
#       'liveness': 0.447,
#       'valence': 0.302,
#       'tempo': 111.021,
#       'type': 'audio_features',
#       'id': '4XRvI0XtqdOGYeC36VkbwA',
#       'uri': 'spotify:track:4XRvI0XtqdOGYeC36VkbwA',
#       'track_href': 'https://api.spotify.com/v1/tracks/4XRvI0XtqdOGYeC36VkbwA',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4XRvI0XtqdOGYeC36VkbwA',
#       'duration_ms': 263080,
#       'time_signature': 4}},
#     'What Feels Like Eternity': {'track_id': '4JmXokIIxfoS3XdhkHUBDw',
#      'disc_number': 1,
#      'duration_ms': 217813,
#      'track_number': 3,
#      'audio_information': {'danceability': 0.53,
#       'energy': 0.767,
#       'key': 5,
#       'loudness': -4.947,
#       'mode': 0,
#       'speechiness': 0.0406,
#       'acousticness': 0.0834,
#       'instrumentalness': 3.06e-05,
#       'liveness': 0.0791,
#       'valence': 0.578,
#       'tempo': 166.04,
#       'type': 'audio_features',
#       'id': '4JmXokIIxfoS3XdhkHUBDw',
#       'uri': 'spotify:track:4JmXokIIxfoS3XdhkHUBDw',
#       'track_href': 'https://api.spotify.com/v1/tracks/4JmXokIIxfoS3XdhkHUBDw',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4JmXokIIxfoS3XdhkHUBDw',
#       'duration_ms': 217813,
#       'time_signature': 4}},
#     'Formentera': {'track_id': '0LeY4wITiOG7R7y5LN77Qt',
#      'disc_number': 1,
#      'duration_ms': 377706,
#      'track_number': 4,
#      'audio_information': {'danceability': 0.428,
#       'energy': 0.839,
#       'key': 5,
#       'loudness': -6.122,
#       'mode': 1,
#       'speechiness': 0.0449,
#       'acousticness': 0.0783,
#       'instrumentalness': 0.135,
#       'liveness': 0.191,
#       'valence': 0.413,
#       'tempo': 171.999,
#       'type': 'audio_features',
#       'id': '0LeY4wITiOG7R7y5LN77Qt',
#       'uri': 'spotify:track:0LeY4wITiOG7R7y5LN77Qt',
#       'track_href': 'https://api.spotify.com/v1/tracks/0LeY4wITiOG7R7y5LN77Qt',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0LeY4wITiOG7R7y5LN77Qt',
#       'duration_ms': 377707,
#       'time_signature': 4}},
#     'Enemies of the Ocean': {'track_id': '4HKitUJYoJjJRATXhSuDlP',
#      'disc_number': 1,
#      'duration_ms': 313626,
#      'track_number': 5,
#      'audio_information': {'danceability': 0.592,
#       'energy': 0.603,
#       'key': 1,
#       'loudness': -6.528,
#       'mode': 1,
#       'speechiness': 0.0265,
#       'acousticness': 0.00215,
#       'instrumentalness': 0.0415,
#       'liveness': 0.0898,
#       'valence': 0.33,
#       'tempo': 135.017,
#       'type': 'audio_features',
#       'id': '4HKitUJYoJjJRATXhSuDlP',
#       'uri': 'spotify:track:4HKitUJYoJjJRATXhSuDlP',
#       'track_href': 'https://api.spotify.com/v1/tracks/4HKitUJYoJjJRATXhSuDlP',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4HKitUJYoJjJRATXhSuDlP',
#       'duration_ms': 313627,
#       'time_signature': 4}},
#     'I Will Never Settle': {'track_id': '2HGb4rrJbTuX9f1GPe0UaN',
#      'disc_number': 1,
#      'duration_ms': 300600,
#      'track_number': 6,
#      'audio_information': {'danceability': 0.382,
#       'energy': 0.697,
#       'key': 10,
#       'loudness': -6.423,
#       'mode': 1,
#       'speechiness': 0.0385,
#       'acousticness': 0.0311,
#       'instrumentalness': 0.0362,
#       'liveness': 0.0823,
#       'valence': 0.2,
#       'tempo': 156.021,
#       'type': 'audio_features',
#       'id': '2HGb4rrJbTuX9f1GPe0UaN',
#       'uri': 'spotify:track:2HGb4rrJbTuX9f1GPe0UaN',
#       'track_href': 'https://api.spotify.com/v1/tracks/2HGb4rrJbTuX9f1GPe0UaN',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2HGb4rrJbTuX9f1GPe0UaN',
#       'duration_ms': 300600,
#       'time_signature': 4}},
#     'False Dichotomy': {'track_id': '6Lg3XL27eplXv3TENt2Twa',
#      'disc_number': 1,
#      'duration_ms': 219866,
#      'track_number': 7,
#      'audio_information': {'danceability': 0.549,
#       'energy': 0.845,
#       'key': 0,
#       'loudness': -4.931,
#       'mode': 1,
#       'speechiness': 0.0265,
#       'acousticness': 0.000156,
#       'instrumentalness': 1.58e-05,
#       'liveness': 0.378,
#       'valence': 0.503,
#       'tempo': 106.963,
#       'type': 'audio_features',
#       'id': '6Lg3XL27eplXv3TENt2Twa',
#       'uri': 'spotify:track:6Lg3XL27eplXv3TENt2Twa',
#       'track_href': 'https://api.spotify.com/v1/tracks/6Lg3XL27eplXv3TENt2Twa',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Lg3XL27eplXv3TENt2Twa',
#       'duration_ms': 219867,
#       'time_signature': 4}},
#     'Oh Please': {'track_id': '3HSP58zTPzeLgThKMho5sh',
#      'disc_number': 1,
#      'duration_ms': 252960,
#      'track_number': 8,
#      'audio_information': {'danceability': 0.617,
#       'energy': 0.899,
#       'key': 1,
#       'loudness': -3.939,
#       'mode': 1,
#       'speechiness': 0.0405,
#       'acousticness': 0.00843,
#       'instrumentalness': 0.0018,
#       'liveness': 0.108,
#       'valence': 0.325,
#       'tempo': 123.01,
#       'type': 'audio_features',
#       'id': '3HSP58zTPzeLgThKMho5sh',
#       'uri': 'spotify:track:3HSP58zTPzeLgThKMho5sh',
#       'track_href': 'https://api.spotify.com/v1/tracks/3HSP58zTPzeLgThKMho5sh',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3HSP58zTPzeLgThKMho5sh',
#       'duration_ms': 252960,
#       'time_signature': 4}},
#     'Paths in the Sky': {'track_id': '2O8woslDxsXfPoLjhpl2Pi',
#      'disc_number': 1,
#      'duration_ms': 290680,
#      'track_number': 9,
#      'audio_information': {'danceability': 0.549,
#       'energy': 0.798,
#       'key': 10,
#       'loudness': -6.621,
#       'mode': 1,
#       'speechiness': 0.0385,
#       'acousticness': 0.115,
#       'instrumentalness': 0.216,
#       'liveness': 0.101,
#       'valence': 0.172,
#       'tempo': 123.992,
#       'type': 'audio_features',
#       'id': '2O8woslDxsXfPoLjhpl2Pi',
#       'uri': 'spotify:track:2O8woslDxsXfPoLjhpl2Pi',
#       'track_href': 'https://api.spotify.com/v1/tracks/2O8woslDxsXfPoLjhpl2Pi',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2O8woslDxsXfPoLjhpl2Pi',
#       'duration_ms': 290680,
#       'time_signature': 4}}},
#    'label': 'Metric Music International, Inc.'},
#   'Art of Doubt': {'album_id': '234lxLeeuQCxSumvL3gB2z',
#    'release_date': '2018-09-21',
#    'total_tracks': 12,
#    'tracklist': {'Dark Saturday': {'track_id': '7hXFB9EQGSMDhRINv4iyyV',
#      'disc_number': 1,
#      'duration_ms': 230013,
#      'track_number': 1,
#      'audio_information': {'danceability': 0.512,
#       'energy': 0.917,
#       'key': 3,
#       'loudness': -3.688,
#       'mode': 1,
#       'speechiness': 0.0801,
#       'acousticness': 0.000171,
#       'instrumentalness': 0.187,
#       'liveness': 0.392,
#       'valence': 0.243,
#       'tempo': 133.477,
#       'type': 'audio_features',
#       'id': '7hXFB9EQGSMDhRINv4iyyV',
#       'uri': 'spotify:track:7hXFB9EQGSMDhRINv4iyyV',
#       'track_href': 'https://api.spotify.com/v1/tracks/7hXFB9EQGSMDhRINv4iyyV',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7hXFB9EQGSMDhRINv4iyyV',
#       'duration_ms': 230013,
#       'time_signature': 4}},
#     'Love You Back': {'track_id': '72RNY9FLIkDWPeyBLYrKWi',
#      'disc_number': 1,
#      'duration_ms': 247413,
#      'track_number': 2,
#      'audio_information': {'danceability': 0.573,
#       'energy': 0.796,
#       'key': 4,
#       'loudness': -5.546,
#       'mode': 0,
#       'speechiness': 0.0278,
#       'acousticness': 0.00993,
#       'instrumentalness': 8.02e-06,
#       'liveness': 0.373,
#       'valence': 0.491,
#       'tempo': 91.973,
#       'type': 'audio_features',
#       'id': '72RNY9FLIkDWPeyBLYrKWi',
#       'uri': 'spotify:track:72RNY9FLIkDWPeyBLYrKWi',
#       'track_href': 'https://api.spotify.com/v1/tracks/72RNY9FLIkDWPeyBLYrKWi',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/72RNY9FLIkDWPeyBLYrKWi',
#       'duration_ms': 247413,
#       'time_signature': 4}},
#     'Die Happy': {'track_id': '6dxqMJlvRHSFXcPjijZvtO',
#      'disc_number': 1,
#      'duration_ms': 245760,
#      'track_number': 3,
#      'audio_information': {'danceability': 0.539,
#       'energy': 0.859,
#       'key': 8,
#       'loudness': -6.464,
#       'mode': 1,
#       'speechiness': 0.0302,
#       'acousticness': 0.00176,
#       'instrumentalness': 0.000236,
#       'liveness': 0.335,
#       'valence': 0.343,
#       'tempo': 93.982,
#       'type': 'audio_features',
#       'id': '6dxqMJlvRHSFXcPjijZvtO',
#       'uri': 'spotify:track:6dxqMJlvRHSFXcPjijZvtO',
#       'track_href': 'https://api.spotify.com/v1/tracks/6dxqMJlvRHSFXcPjijZvtO',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6dxqMJlvRHSFXcPjijZvtO',
#       'duration_ms': 245760,
#       'time_signature': 4}},
#     'Now or Never Now': {'track_id': '4Eh6mc993AIHTEpj3LFIlp',
#      'disc_number': 1,
#      'duration_ms': 379720,
#      'track_number': 4,
#      'audio_information': {'danceability': 0.531,
#       'energy': 0.862,
#       'key': 1,
#       'loudness': -7.486,
#       'mode': 1,
#       'speechiness': 0.0275,
#       'acousticness': 0.0075,
#       'instrumentalness': 0.338,
#       'liveness': 0.0996,
#       'valence': 0.577,
#       'tempo': 117.996,
#       'type': 'audio_features',
#       'id': '4Eh6mc993AIHTEpj3LFIlp',
#       'uri': 'spotify:track:4Eh6mc993AIHTEpj3LFIlp',
#       'track_href': 'https://api.spotify.com/v1/tracks/4Eh6mc993AIHTEpj3LFIlp',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4Eh6mc993AIHTEpj3LFIlp',
#       'duration_ms': 379720,
#       'time_signature': 4}},
#     'Art of Doubt': {'track_id': '3L2ZZQmhRrgUV1O6CXiMjM',
#      'disc_number': 1,
#      'duration_ms': 290546,
#      'track_number': 5,
#      'audio_information': {'danceability': 0.388,
#       'energy': 0.936,
#       'key': 4,
#       'loudness': -4.223,
#       'mode': 0,
#       'speechiness': 0.0589,
#       'acousticness': 0.000166,
#       'instrumentalness': 0.205,
#       'liveness': 0.387,
#       'valence': 0.507,
#       'tempo': 158.039,
#       'type': 'audio_features',
#       'id': '3L2ZZQmhRrgUV1O6CXiMjM',
#       'uri': 'spotify:track:3L2ZZQmhRrgUV1O6CXiMjM',
#       'track_href': 'https://api.spotify.com/v1/tracks/3L2ZZQmhRrgUV1O6CXiMjM',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3L2ZZQmhRrgUV1O6CXiMjM',
#       'duration_ms': 290547,
#       'time_signature': 4}},
#     'Underline the Black': {'track_id': '2IalHERNOUCeHMCqEbwCSs',
#      'disc_number': 1,
#      'duration_ms': 275506,
#      'track_number': 6,
#      'audio_information': {'danceability': 0.55,
#       'energy': 0.865,
#       'key': 11,
#       'loudness': -5.587,
#       'mode': 0,
#       'speechiness': 0.0394,
#       'acousticness': 0.099,
#       'instrumentalness': 0.878,
#       'liveness': 0.0761,
#       'valence': 0.483,
#       'tempo': 125.03,
#       'type': 'audio_features',
#       'id': '2IalHERNOUCeHMCqEbwCSs',
#       'uri': 'spotify:track:2IalHERNOUCeHMCqEbwCSs',
#       'track_href': 'https://api.spotify.com/v1/tracks/2IalHERNOUCeHMCqEbwCSs',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2IalHERNOUCeHMCqEbwCSs',
#       'duration_ms': 275507,
#       'time_signature': 4}},
#     'Dressed to Suppress': {'track_id': '34hE6jusc190ds6yzcIJd6',
#      'disc_number': 1,
#      'duration_ms': 342520,
#      'track_number': 7,
#      'audio_information': {'danceability': 0.393,
#       'energy': 0.784,
#       'key': 6,
#       'loudness': -5.614,
#       'mode': 1,
#       'speechiness': 0.0343,
#       'acousticness': 4.49e-05,
#       'instrumentalness': 0.648,
#       'liveness': 0.21,
#       'valence': 0.114,
#       'tempo': 116.024,
#       'type': 'audio_features',
#       'id': '34hE6jusc190ds6yzcIJd6',
#       'uri': 'spotify:track:34hE6jusc190ds6yzcIJd6',
#       'track_href': 'https://api.spotify.com/v1/tracks/34hE6jusc190ds6yzcIJd6',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/34hE6jusc190ds6yzcIJd6',
#       'duration_ms': 342520,
#       'time_signature': 4}},
#     'Risk': {'track_id': '64ZYwei2k93G3muzSPXzRy',
#      'disc_number': 1,
#      'duration_ms': 324720,
#      'track_number': 8,
#      'audio_information': {'danceability': 0.527,
#       'energy': 0.921,
#       'key': 6,
#       'loudness': -4.572,
#       'mode': 0,
#       'speechiness': 0.0396,
#       'acousticness': 0.0287,
#       'instrumentalness': 0.0191,
#       'liveness': 0.241,
#       'valence': 0.488,
#       'tempo': 155.953,
#       'type': 'audio_features',
#       'id': '64ZYwei2k93G3muzSPXzRy',
#       'uri': 'spotify:track:64ZYwei2k93G3muzSPXzRy',
#       'track_href': 'https://api.spotify.com/v1/tracks/64ZYwei2k93G3muzSPXzRy',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/64ZYwei2k93G3muzSPXzRy',
#       'duration_ms': 324720,
#       'time_signature': 4}},
#     'Seven Rules': {'track_id': '4BDHN09qCptAVZ96SSPzCu',
#      'disc_number': 1,
#      'duration_ms': 308826,
#      'track_number': 9,
#      'audio_information': {'danceability': 0.572,
#       'energy': 0.467,
#       'key': 7,
#       'loudness': -8.399,
#       'mode': 0,
#       'speechiness': 0.0273,
#       'acousticness': 0.196,
#       'instrumentalness': 0.799,
#       'liveness': 0.0896,
#       'valence': 0.348,
#       'tempo': 125.051,
#       'type': 'audio_features',
#       'id': '4BDHN09qCptAVZ96SSPzCu',
#       'uri': 'spotify:track:4BDHN09qCptAVZ96SSPzCu',
#       'track_href': 'https://api.spotify.com/v1/tracks/4BDHN09qCptAVZ96SSPzCu',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4BDHN09qCptAVZ96SSPzCu',
#       'duration_ms': 308827,
#       'time_signature': 4}},
#     'Holding Out': {'track_id': '6nqtdFXwgHAZjOqJKbreiD',
#      'disc_number': 1,
#      'duration_ms': 237493,
#      'track_number': 10,
#      'audio_information': {'danceability': 0.566,
#       'energy': 0.729,
#       'key': 0,
#       'loudness': -5.541,
#       'mode': 1,
#       'speechiness': 0.031,
#       'acousticness': 0.00191,
#       'instrumentalness': 8.68e-05,
#       'liveness': 0.128,
#       'valence': 0.373,
#       'tempo': 119.971,
#       'type': 'audio_features',
#       'id': '6nqtdFXwgHAZjOqJKbreiD',
#       'uri': 'spotify:track:6nqtdFXwgHAZjOqJKbreiD',
#       'track_href': 'https://api.spotify.com/v1/tracks/6nqtdFXwgHAZjOqJKbreiD',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6nqtdFXwgHAZjOqJKbreiD',
#       'duration_ms': 237493,
#       'time_signature': 4}},
#     'Anticipate': {'track_id': '09OvnPdvfGkddh71yQbNoA',
#      'disc_number': 1,
#      'duration_ms': 225266,
#      'track_number': 11,
#      'audio_information': {'danceability': 0.27,
#       'energy': 0.685,
#       'key': 7,
#       'loudness': -7.284,
#       'mode': 0,
#       'speechiness': 0.0317,
#       'acousticness': 0.0652,
#       'instrumentalness': 0.00038,
#       'liveness': 0.193,
#       'valence': 0.417,
#       'tempo': 92.794,
#       'type': 'audio_features',
#       'id': '09OvnPdvfGkddh71yQbNoA',
#       'uri': 'spotify:track:09OvnPdvfGkddh71yQbNoA',
#       'track_href': 'https://api.spotify.com/v1/tracks/09OvnPdvfGkddh71yQbNoA',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/09OvnPdvfGkddh71yQbNoA',
#       'duration_ms': 225267,
#       'time_signature': 3}},
#     'No Lights on the Horizon': {'track_id': '08TYI9OeUb2DkxkUqjolIW',
#      'disc_number': 1,
#      'duration_ms': 394386,
#      'track_number': 12,
#      'audio_information': {'danceability': 0.612,
#       'energy': 0.551,
#       'key': 5,
#       'loudness': -9.317,
#       'mode': 1,
#       'speechiness': 0.0236,
#       'acousticness': 0.0221,
#       'instrumentalness': 0.293,
#       'liveness': 0.111,
#       'valence': 0.305,
#       'tempo': 109.007,
#       'type': 'audio_features',
#       'id': '08TYI9OeUb2DkxkUqjolIW',
#       'uri': 'spotify:track:08TYI9OeUb2DkxkUqjolIW',
#       'track_href': 'https://api.spotify.com/v1/tracks/08TYI9OeUb2DkxkUqjolIW',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/08TYI9OeUb2DkxkUqjolIW',
#       'duration_ms': 394387,
#       'time_signature': 4}}},
#    'label': 'Metric Productions Inc.'},
#   'Pagans in Vegas': {'album_id': '4VgmyHz9rPSBRfIP3qGiPT',
#    'release_date': '2015-09-18',
#    'total_tracks': 13,
#    'tracklist': {'Lie Lie Lie': {'track_id': '0PpXXdxoGYUpCqk1Qy7Olu',
#      'disc_number': 1,
#      'duration_ms': 255426,
#      'track_number': 1,
#      'audio_information': {'danceability': 0.355,
#       'energy': 0.817,
#       'key': 9,
#       'loudness': -5.348,
#       'mode': 1,
#       'speechiness': 0.0606,
#       'acousticness': 0.278,
#       'instrumentalness': 9.09e-05,
#       'liveness': 0.0816,
#       'valence': 0.34,
#       'tempo': 131.933,
#       'type': 'audio_features',
#       'id': '0PpXXdxoGYUpCqk1Qy7Olu',
#       'uri': 'spotify:track:0PpXXdxoGYUpCqk1Qy7Olu',
#       'track_href': 'https://api.spotify.com/v1/tracks/0PpXXdxoGYUpCqk1Qy7Olu',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0PpXXdxoGYUpCqk1Qy7Olu',
#       'duration_ms': 255427,
#       'time_signature': 4}},
#     'Fortunes': {'track_id': '1zjk2izOsoupl12xR4j84x',
#      'disc_number': 1,
#      'duration_ms': 252813,
#      'track_number': 2,
#      'audio_information': {'danceability': 0.565,
#       'energy': 0.725,
#       'key': 11,
#       'loudness': -7.402,
#       'mode': 0,
#       'speechiness': 0.0272,
#       'acousticness': 0.0125,
#       'instrumentalness': 0.0431,
#       'liveness': 0.359,
#       'valence': 0.339,
#       'tempo': 145.021,
#       'type': 'audio_features',
#       'id': '1zjk2izOsoupl12xR4j84x',
#       'uri': 'spotify:track:1zjk2izOsoupl12xR4j84x',
#       'track_href': 'https://api.spotify.com/v1/tracks/1zjk2izOsoupl12xR4j84x',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1zjk2izOsoupl12xR4j84x',
#       'duration_ms': 252813,
#       'time_signature': 4}},
#     'The Shade': {'track_id': '7wE3CEBs93FJk9DRMJ2unA',
#      'disc_number': 1,
#      'duration_ms': 216360,
#      'track_number': 3,
#      'audio_information': {'danceability': 0.597,
#       'energy': 0.814,
#       'key': 5,
#       'loudness': -3.833,
#       'mode': 1,
#       'speechiness': 0.0317,
#       'acousticness': 0.0289,
#       'instrumentalness': 9.24e-05,
#       'liveness': 0.0663,
#       'valence': 0.629,
#       'tempo': 94.006,
#       'type': 'audio_features',
#       'id': '7wE3CEBs93FJk9DRMJ2unA',
#       'uri': 'spotify:track:7wE3CEBs93FJk9DRMJ2unA',
#       'track_href': 'https://api.spotify.com/v1/tracks/7wE3CEBs93FJk9DRMJ2unA',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7wE3CEBs93FJk9DRMJ2unA',
#       'duration_ms': 216360,
#       'time_signature': 4}},
#     'Celebrate': {'track_id': '7H9NplKGzBsyeFcgGINqsO',
#      'disc_number': 1,
#      'duration_ms': 240080,
#      'track_number': 4,
#      'audio_information': {'danceability': 0.585,
#       'energy': 0.763,
#       'key': 7,
#       'loudness': -6.286,
#       'mode': 0,
#       'speechiness': 0.0319,
#       'acousticness': 0.00591,
#       'instrumentalness': 5.82e-06,
#       'liveness': 0.134,
#       'valence': 0.145,
#       'tempo': 131.983,
#       'type': 'audio_features',
#       'id': '7H9NplKGzBsyeFcgGINqsO',
#       'uri': 'spotify:track:7H9NplKGzBsyeFcgGINqsO',
#       'track_href': 'https://api.spotify.com/v1/tracks/7H9NplKGzBsyeFcgGINqsO',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7H9NplKGzBsyeFcgGINqsO',
#       'duration_ms': 240080,
#       'time_signature': 4}},
#     'Cascades': {'track_id': '1pBg92BG0627JeeVY6eGym',
#      'disc_number': 1,
#      'duration_ms': 324426,
#      'track_number': 5,
#      'audio_information': {'danceability': 0.68,
#       'energy': 0.778,
#       'key': 0,
#       'loudness': -7.022,
#       'mode': 0,
#       'speechiness': 0.0376,
#       'acousticness': 0.0738,
#       'instrumentalness': 0.827,
#       'liveness': 0.088,
#       'valence': 0.593,
#       'tempo': 105.996,
#       'type': 'audio_features',
#       'id': '1pBg92BG0627JeeVY6eGym',
#       'uri': 'spotify:track:1pBg92BG0627JeeVY6eGym',
#       'track_href': 'https://api.spotify.com/v1/tracks/1pBg92BG0627JeeVY6eGym',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1pBg92BG0627JeeVY6eGym',
#       'duration_ms': 324427,
#       'time_signature': 4}},
#     'For Kicks': {'track_id': '15aH0Y46kj4xJBRFNxKdzu',
#      'disc_number': 1,
#      'duration_ms': 296506,
#      'track_number': 6,
#      'audio_information': {'danceability': 0.622,
#       'energy': 0.699,
#       'key': 1,
#       'loudness': -5.898,
#       'mode': 0,
#       'speechiness': 0.0256,
#       'acousticness': 0.118,
#       'instrumentalness': 0.00027,
#       'liveness': 0.0654,
#       'valence': 0.617,
#       'tempo': 109.985,
#       'type': 'audio_features',
#       'id': '15aH0Y46kj4xJBRFNxKdzu',
#       'uri': 'spotify:track:15aH0Y46kj4xJBRFNxKdzu',
#       'track_href': 'https://api.spotify.com/v1/tracks/15aH0Y46kj4xJBRFNxKdzu',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/15aH0Y46kj4xJBRFNxKdzu',
#       'duration_ms': 296507,
#       'time_signature': 4}},
#     'Too Bad, So Sad': {'track_id': '4fl6E2FVzi2FVcBZmvQyfN',
#      'disc_number': 1,
#      'duration_ms': 204973,
#      'track_number': 7,
#      'audio_information': {'danceability': 0.581,
#       'energy': 0.872,
#       'key': 2,
#       'loudness': -5.495,
#       'mode': 0,
#       'speechiness': 0.0311,
#       'acousticness': 0.000248,
#       'instrumentalness': 0.00272,
#       'liveness': 0.298,
#       'valence': 0.474,
#       'tempo': 101.278,
#       'type': 'audio_features',
#       'id': '4fl6E2FVzi2FVcBZmvQyfN',
#       'uri': 'spotify:track:4fl6E2FVzi2FVcBZmvQyfN',
#       'track_href': 'https://api.spotify.com/v1/tracks/4fl6E2FVzi2FVcBZmvQyfN',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4fl6E2FVzi2FVcBZmvQyfN',
#       'duration_ms': 204973,
#       'time_signature': 3}},
#     'Other Side': {'track_id': '2mUGlRJJHKxG6D8CFq7l0y',
#      'disc_number': 1,
#      'duration_ms': 231600,
#      'track_number': 8,
#      'audio_information': {'danceability': 0.578,
#       'energy': 0.723,
#       'key': 0,
#       'loudness': -6.21,
#       'mode': 1,
#       'speechiness': 0.0265,
#       'acousticness': 0.0133,
#       'instrumentalness': 0.0054,
#       'liveness': 0.0677,
#       'valence': 0.169,
#       'tempo': 127.032,
#       'type': 'audio_features',
#       'id': '2mUGlRJJHKxG6D8CFq7l0y',
#       'uri': 'spotify:track:2mUGlRJJHKxG6D8CFq7l0y',
#       'track_href': 'https://api.spotify.com/v1/tracks/2mUGlRJJHKxG6D8CFq7l0y',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2mUGlRJJHKxG6D8CFq7l0y',
#       'duration_ms': 231600,
#       'time_signature': 4}},
#     'Blind Valentine': {'track_id': '002zygf5KBABh8Q40gmxRu',
#      'disc_number': 1,
#      'duration_ms': 202146,
#      'track_number': 9,
#      'audio_information': {'danceability': 0.604,
#       'energy': 0.63,
#       'key': 3,
#       'loudness': -6.01,
#       'mode': 1,
#       'speechiness': 0.0358,
#       'acousticness': 0.13,
#       'instrumentalness': 1.03e-06,
#       'liveness': 0.461,
#       'valence': 0.435,
#       'tempo': 140.054,
#       'type': 'audio_features',
#       'id': '002zygf5KBABh8Q40gmxRu',
#       'uri': 'spotify:track:002zygf5KBABh8Q40gmxRu',
#       'track_href': 'https://api.spotify.com/v1/tracks/002zygf5KBABh8Q40gmxRu',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/002zygf5KBABh8Q40gmxRu',
#       'duration_ms': 202147,
#       'time_signature': 4}},
#     'The Governess': {'track_id': '6shuCEZYdP3ngBKiSLMmAu',
#      'disc_number': 1,
#      'duration_ms': 241080,
#      'track_number': 10,
#      'audio_information': {'danceability': 0.627,
#       'energy': 0.643,
#       'key': 2,
#       'loudness': -6.655,
#       'mode': 1,
#       'speechiness': 0.0262,
#       'acousticness': 0.0134,
#       'instrumentalness': 5.24e-05,
#       'liveness': 0.108,
#       'valence': 0.614,
#       'tempo': 80.024,
#       'type': 'audio_features',
#       'id': '6shuCEZYdP3ngBKiSLMmAu',
#       'uri': 'spotify:track:6shuCEZYdP3ngBKiSLMmAu',
#       'track_href': 'https://api.spotify.com/v1/tracks/6shuCEZYdP3ngBKiSLMmAu',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6shuCEZYdP3ngBKiSLMmAu',
#       'duration_ms': 241080,
#       'time_signature': 4}},
#     'The Face Part I': {'track_id': '3PXXroxI0gu3qCZQ8fRRd4',
#      'disc_number': 1,
#      'duration_ms': 301680,
#      'track_number': 11,
#      'audio_information': {'danceability': 0.606,
#       'energy': 0.63,
#       'key': 9,
#       'loudness': -8.174,
#       'mode': 0,
#       'speechiness': 0.0456,
#       'acousticness': 0.175,
#       'instrumentalness': 0.886,
#       'liveness': 0.549,
#       'valence': 0.502,
#       'tempo': 125.977,
#       'type': 'audio_features',
#       'id': '3PXXroxI0gu3qCZQ8fRRd4',
#       'uri': 'spotify:track:3PXXroxI0gu3qCZQ8fRRd4',
#       'track_href': 'https://api.spotify.com/v1/tracks/3PXXroxI0gu3qCZQ8fRRd4',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3PXXroxI0gu3qCZQ8fRRd4',
#       'duration_ms': 301680,
#       'time_signature': 4}},
#     'The Face Part II': {'track_id': '72hbs5Gt9X0ArrIf0953gJ',
#      'disc_number': 1,
#      'duration_ms': 200640,
#      'track_number': 12,
#      'audio_information': {'danceability': 0.187,
#       'energy': 0.0199,
#       'key': 7,
#       'loudness': -18.235,
#       'mode': 1,
#       'speechiness': 0.0417,
#       'acousticness': 0.941,
#       'instrumentalness': 0.903,
#       'liveness': 0.0796,
#       'valence': 0.0396,
#       'tempo': 66.947,
#       'type': 'audio_features',
#       'id': '72hbs5Gt9X0ArrIf0953gJ',
#       'uri': 'spotify:track:72hbs5Gt9X0ArrIf0953gJ',
#       'track_href': 'https://api.spotify.com/v1/tracks/72hbs5Gt9X0ArrIf0953gJ',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/72hbs5Gt9X0ArrIf0953gJ',
#       'duration_ms': 200640,
#       'time_signature': 4}},
#     'The Shade - Acoustic': {'track_id': '6GroIBai4llsV2fKXSkw2a',
#      'disc_number': 1,
#      'duration_ms': 192146,
#      'track_number': 13,
#      'audio_information': {'danceability': 0.584,
#       'energy': 0.474,
#       'key': 3,
#       'loudness': -4.891,
#       'mode': 1,
#       'speechiness': 0.028,
#       'acousticness': 0.837,
#       'instrumentalness': 2.37e-06,
#       'liveness': 0.0698,
#       'valence': 0.298,
#       'tempo': 88.927,
#       'type': 'audio_features',
#       'id': '6GroIBai4llsV2fKXSkw2a',
#       'uri': 'spotify:track:6GroIBai4llsV2fKXSkw2a',
#       'track_href': 'https://api.spotify.com/v1/tracks/6GroIBai4llsV2fKXSkw2a',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6GroIBai4llsV2fKXSkw2a',
#       'duration_ms': 192147,
#       'time_signature': 4}}},
#    'label': 'MMI / Crystal Math Music'},
#   'Cosmopolis (Original Motion Picture Soundtrack)': {'album_id': '3ZODeTWdmP8gtOKt4j7oOB',
#    'release_date': '2012-07-10',
#    'total_tracks': 11,
#    'tracklist': {'White Limos': {'track_id': '2ChqZKCD0sIwPSaAZ1NRLp',
#      'disc_number': 1,
#      'duration_ms': 119761,
#      'track_number': 1,
#      'audio_information': {'danceability': 0.429,
#       'energy': 0.674,
#       'key': 2,
#       'loudness': -11.838,
#       'mode': 1,
#       'speechiness': 0.0464,
#       'acousticness': 0.579,
#       'instrumentalness': 0.895,
#       'liveness': 0.0893,
#       'valence': 0.0303,
#       'tempo': 119.946,
#       'type': 'audio_features',
#       'id': '2ChqZKCD0sIwPSaAZ1NRLp',
#       'uri': 'spotify:track:2ChqZKCD0sIwPSaAZ1NRLp',
#       'track_href': 'https://api.spotify.com/v1/tracks/2ChqZKCD0sIwPSaAZ1NRLp',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2ChqZKCD0sIwPSaAZ1NRLp',
#       'duration_ms': 119762,
#       'time_signature': 3}},
#     'Long to Live': {'track_id': '40hHaKQV7XxeUEAAzKs5AE',
#      'disc_number': 1,
#      'duration_ms': 266689,
#      'track_number': 2,
#      'audio_information': {'danceability': 0.417,
#       'energy': 0.754,
#       'key': 0,
#       'loudness': -6.615,
#       'mode': 1,
#       'speechiness': 0.0397,
#       'acousticness': 0.125,
#       'instrumentalness': 0.908,
#       'liveness': 0.118,
#       'valence': 0.284,
#       'tempo': 119.995,
#       'type': 'audio_features',
#       'id': '40hHaKQV7XxeUEAAzKs5AE',
#       'uri': 'spotify:track:40hHaKQV7XxeUEAAzKs5AE',
#       'track_href': 'https://api.spotify.com/v1/tracks/40hHaKQV7XxeUEAAzKs5AE',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/40hHaKQV7XxeUEAAzKs5AE',
#       'duration_ms': 266689,
#       'time_signature': 4}},
#     'Rat Men': {'track_id': '4Lhbrg0lGEqnH2DihYFLaa',
#      'disc_number': 1,
#      'duration_ms': 284307,
#      'track_number': 3,
#      'audio_information': {'danceability': 0.0822,
#       'energy': 0.256,
#       'key': 10,
#       'loudness': -16.07,
#       'mode': 1,
#       'speechiness': 0.0369,
#       'acousticness': 0.454,
#       'instrumentalness': 0.938,
#       'liveness': 0.119,
#       'valence': 0.0257,
#       'tempo': 171.635,
#       'type': 'audio_features',
#       'id': '4Lhbrg0lGEqnH2DihYFLaa',
#       'uri': 'spotify:track:4Lhbrg0lGEqnH2DihYFLaa',
#       'track_href': 'https://api.spotify.com/v1/tracks/4Lhbrg0lGEqnH2DihYFLaa',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4Lhbrg0lGEqnH2DihYFLaa',
#       'duration_ms': 284307,
#       'time_signature': 4}},
#     'Asymmetrical': {'track_id': '7rB6J3JwWC0xh9Te0ujXMz',
#      'disc_number': 1,
#      'duration_ms': 251523,
#      'track_number': 4,
#      'audio_information': {'danceability': 0.465,
#       'energy': 0.387,
#       'key': 4,
#       'loudness': -18.806,
#       'mode': 0,
#       'speechiness': 0.0362,
#       'acousticness': 0.731,
#       'instrumentalness': 0.869,
#       'liveness': 0.0882,
#       'valence': 0.0722,
#       'tempo': 119.988,
#       'type': 'audio_features',
#       'id': '7rB6J3JwWC0xh9Te0ujXMz',
#       'uri': 'spotify:track:7rB6J3JwWC0xh9Te0ujXMz',
#       'track_href': 'https://api.spotify.com/v1/tracks/7rB6J3JwWC0xh9Te0ujXMz',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7rB6J3JwWC0xh9Te0ujXMz',
#       'duration_ms': 251524,
#       'time_signature': 4}},
#     "I Don't Want to Wake Up": {'track_id': '57DU5cprVL1u3Pedn1HYXv',
#      'disc_number': 1,
#      'duration_ms': 254755,
#      'track_number': 5,
#      'audio_information': {'danceability': 0.405,
#       'energy': 0.746,
#       'key': 2,
#       'loudness': -6.551,
#       'mode': 1,
#       'speechiness': 0.0456,
#       'acousticness': 4.82e-05,
#       'instrumentalness': 0.916,
#       'liveness': 0.12,
#       'valence': 0.335,
#       'tempo': 119.989,
#       'type': 'audio_features',
#       'id': '57DU5cprVL1u3Pedn1HYXv',
#       'uri': 'spotify:track:57DU5cprVL1u3Pedn1HYXv',
#       'track_href': 'https://api.spotify.com/v1/tracks/57DU5cprVL1u3Pedn1HYXv',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/57DU5cprVL1u3Pedn1HYXv',
#       'duration_ms': 254755,
#       'time_signature': 4}},
#     'A Credible Threat': {'track_id': '0s7YrKwFS6zbcPF0PeBKiI',
#      'disc_number': 1,
#      'duration_ms': 113553,
#      'track_number': 6,
#      'audio_information': {'danceability': 0.387,
#       'energy': 0.18,
#       'key': 9,
#       'loudness': -22.776,
#       'mode': 1,
#       'speechiness': 0.0492,
#       'acousticness': 0.891,
#       'instrumentalness': 0.906,
#       'liveness': 0.0973,
#       'valence': 0.0373,
#       'tempo': 95.982,
#       'type': 'audio_features',
#       'id': '0s7YrKwFS6zbcPF0PeBKiI',
#       'uri': 'spotify:track:0s7YrKwFS6zbcPF0PeBKiI',
#       'track_href': 'https://api.spotify.com/v1/tracks/0s7YrKwFS6zbcPF0PeBKiI',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0s7YrKwFS6zbcPF0PeBKiI',
#       'duration_ms': 113553,
#       'time_signature': 3}},
#     'Call Me Home': {'track_id': '4WcgtX0njtNbYm1zHbKFF7',
#      'disc_number': 1,
#      'duration_ms': 156985,
#      'track_number': 7,
#      'audio_information': {'danceability': 0.575,
#       'energy': 0.422,
#       'key': 9,
#       'loudness': -11.064,
#       'mode': 0,
#       'speechiness': 0.031,
#       'acousticness': 0.533,
#       'instrumentalness': 0.574,
#       'liveness': 0.1,
#       'valence': 0.0696,
#       'tempo': 96.017,
#       'type': 'audio_features',
#       'id': '4WcgtX0njtNbYm1zHbKFF7',
#       'uri': 'spotify:track:4WcgtX0njtNbYm1zHbKFF7',
#       'track_href': 'https://api.spotify.com/v1/tracks/4WcgtX0njtNbYm1zHbKFF7',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4WcgtX0njtNbYm1zHbKFF7',
#       'duration_ms': 156986,
#       'time_signature': 4}},
#     'Haircut': {'track_id': '3gDrCOpz5O7A5yK0L1waa1',
#      'disc_number': 1,
#      'duration_ms': 238739,
#      'track_number': 8,
#      'audio_information': {'danceability': 0.146,
#       'energy': 0.13,
#       'key': 0,
#       'loudness': -18.531,
#       'mode': 1,
#       'speechiness': 0.0403,
#       'acousticness': 0.677,
#       'instrumentalness': 0.918,
#       'liveness': 0.099,
#       'valence': 0.03,
#       'tempo': 171.936,
#       'type': 'audio_features',
#       'id': '3gDrCOpz5O7A5yK0L1waa1',
#       'uri': 'spotify:track:3gDrCOpz5O7A5yK0L1waa1',
#       'track_href': 'https://api.spotify.com/v1/tracks/3gDrCOpz5O7A5yK0L1waa1',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3gDrCOpz5O7A5yK0L1waa1',
#       'duration_ms': 238740,
#       'time_signature': 3}},
#     'Mecca': {'track_id': '4MDZzXHbQOR4tEFyuu5g2E',
#      'disc_number': 1,
#      'duration_ms': 175396,
#      'track_number': 9,
#      'audio_information': {'danceability': 0.681,
#       'energy': 0.451,
#       'key': 10,
#       'loudness': -8.321,
#       'mode': 0,
#       'speechiness': 0.121,
#       'acousticness': 0.0627,
#       'instrumentalness': 0.299,
#       'liveness': 0.102,
#       'valence': 0.611,
#       'tempo': 172.023,
#       'type': 'audio_features',
#       'id': '4MDZzXHbQOR4tEFyuu5g2E',
#       'uri': 'spotify:track:4MDZzXHbQOR4tEFyuu5g2E',
#       'track_href': 'https://api.spotify.com/v1/tracks/4MDZzXHbQOR4tEFyuu5g2E',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4MDZzXHbQOR4tEFyuu5g2E',
#       'duration_ms': 175396,
#       'time_signature': 4}},
#     'The Gun': {'track_id': '3SwWuaOnikBKw7aaHHgTzB',
#      'disc_number': 1,
#      'duration_ms': 154758,
#      'track_number': 10,
#      'audio_information': {'danceability': 0.474,
#       'energy': 0.193,
#       'key': 2,
#       'loudness': -20.186,
#       'mode': 1,
#       'speechiness': 0.0294,
#       'acousticness': 0.92,
#       'instrumentalness': 0.91,
#       'liveness': 0.09,
#       'valence': 0.0487,
#       'tempo': 96.008,
#       'type': 'audio_features',
#       'id': '3SwWuaOnikBKw7aaHHgTzB',
#       'uri': 'spotify:track:3SwWuaOnikBKw7aaHHgTzB',
#       'track_href': 'https://api.spotify.com/v1/tracks/3SwWuaOnikBKw7aaHHgTzB',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3SwWuaOnikBKw7aaHHgTzB',
#       'duration_ms': 154759,
#       'time_signature': 4}},
#     'Benno': {'track_id': '3XiRUEgCkrXI42GqHaUkZw',
#      'disc_number': 1,
#      'duration_ms': 412170,
#      'track_number': 11,
#      'audio_information': {'danceability': 0.33,
#       'energy': 0.431,
#       'key': 2,
#       'loudness': -11.185,
#       'mode': 1,
#       'speechiness': 0.0331,
#       'acousticness': 0.00996,
#       'instrumentalness': 0.813,
#       'liveness': 0.127,
#       'valence': 0.0283,
#       'tempo': 172.014,
#       'type': 'audio_features',
#       'id': '3XiRUEgCkrXI42GqHaUkZw',
#       'uri': 'spotify:track:3XiRUEgCkrXI42GqHaUkZw',
#       'track_href': 'https://api.spotify.com/v1/tracks/3XiRUEgCkrXI42GqHaUkZw',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3XiRUEgCkrXI42GqHaUkZw',
#       'duration_ms': 412171,
#       'time_signature': 4}}},
#    'label': 'Howe Records'},
#   'Synthetica Reflections': {'album_id': '1gAoSd6wqu5TIXamojNlzW',
#    'release_date': '2012-06-12',
#    'total_tracks': 11,
#    'tracklist': {'Reflection #1': {'track_id': '0ySuKssALuf32fq3tEMXBz',
#      'disc_number': 1,
#      'duration_ms': 93741,
#      'track_number': 1,
#      'audio_information': {'danceability': 0.197,
#       'energy': 0.312,
#       'key': 7,
#       'loudness': -14.123,
#       'mode': 1,
#       'speechiness': 0.0344,
#       'acousticness': 0.644,
#       'instrumentalness': 0.749,
#       'liveness': 0.0921,
#       'valence': 0.0359,
#       'tempo': 75.424,
#       'type': 'audio_features',
#       'id': '0ySuKssALuf32fq3tEMXBz',
#       'uri': 'spotify:track:0ySuKssALuf32fq3tEMXBz',
#       'track_href': 'https://api.spotify.com/v1/tracks/0ySuKssALuf32fq3tEMXBz',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0ySuKssALuf32fq3tEMXBz',
#       'duration_ms': 93742,
#       'time_signature': 1}},
#     'Reflection #2': {'track_id': '76EYRTUrZkxPHp1L4dJ0YT',
#      'disc_number': 1,
#      'duration_ms': 151255,
#      'track_number': 2,
#      'audio_information': {'danceability': 0.195,
#       'energy': 0.268,
#       'key': 2,
#       'loudness': -14.19,
#       'mode': 1,
#       'speechiness': 0.0377,
#       'acousticness': 0.11,
#       'instrumentalness': 0.768,
#       'liveness': 0.0754,
#       'valence': 0.0296,
#       'tempo': 110.052,
#       'type': 'audio_features',
#       'id': '76EYRTUrZkxPHp1L4dJ0YT',
#       'uri': 'spotify:track:76EYRTUrZkxPHp1L4dJ0YT',
#       'track_href': 'https://api.spotify.com/v1/tracks/76EYRTUrZkxPHp1L4dJ0YT',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/76EYRTUrZkxPHp1L4dJ0YT',
#       'duration_ms': 151255,
#       'time_signature': 4}},
#     'Reflection #3': {'track_id': '1BzxMx3b2KxeMioFhwZXWd',
#      'disc_number': 1,
#      'duration_ms': 93518,
#      'track_number': 3,
#      'audio_information': {'danceability': 0.194,
#       'energy': 0.271,
#       'key': 4,
#       'loudness': -11.895,
#       'mode': 0,
#       'speechiness': 0.0404,
#       'acousticness': 0.582,
#       'instrumentalness': 0.791,
#       'liveness': 0.141,
#       'valence': 0.121,
#       'tempo': 141.582,
#       'type': 'audio_features',
#       'id': '1BzxMx3b2KxeMioFhwZXWd',
#       'uri': 'spotify:track:1BzxMx3b2KxeMioFhwZXWd',
#       'track_href': 'https://api.spotify.com/v1/tracks/1BzxMx3b2KxeMioFhwZXWd',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1BzxMx3b2KxeMioFhwZXWd',
#       'duration_ms': 93518,
#       'time_signature': 1}},
#     'Reflection #4': {'track_id': '1YQV9dG4W5Aj3cifNOmId0',
#      'disc_number': 1,
#      'duration_ms': 172814,
#      'track_number': 4,
#      'audio_information': {'danceability': 0.16,
#       'energy': 0.197,
#       'key': 11,
#       'loudness': -12.654,
#       'mode': 0,
#       'speechiness': 0.0414,
#       'acousticness': 0.549,
#       'instrumentalness': 0.985,
#       'liveness': 0.286,
#       'valence': 0.16,
#       'tempo': 96.42,
#       'type': 'audio_features',
#       'id': '1YQV9dG4W5Aj3cifNOmId0',
#       'uri': 'spotify:track:1YQV9dG4W5Aj3cifNOmId0',
#       'track_href': 'https://api.spotify.com/v1/tracks/1YQV9dG4W5Aj3cifNOmId0',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1YQV9dG4W5Aj3cifNOmId0',
#       'duration_ms': 172815,
#       'time_signature': 4}},
#     'Reflection #5': {'track_id': '6YenGWxNJxJbLGWbn5Ph4y',
#      'disc_number': 1,
#      'duration_ms': 172099,
#      'track_number': 5,
#      'audio_information': {'danceability': 0.251,
#       'energy': 0.155,
#       'key': 0,
#       'loudness': -20.295,
#       'mode': 0,
#       'speechiness': 0.0479,
#       'acousticness': 0.748,
#       'instrumentalness': 0.979,
#       'liveness': 0.162,
#       'valence': 0.0397,
#       'tempo': 105.046,
#       'type': 'audio_features',
#       'id': '6YenGWxNJxJbLGWbn5Ph4y',
#       'uri': 'spotify:track:6YenGWxNJxJbLGWbn5Ph4y',
#       'track_href': 'https://api.spotify.com/v1/tracks/6YenGWxNJxJbLGWbn5Ph4y',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6YenGWxNJxJbLGWbn5Ph4y',
#       'duration_ms': 172099,
#       'time_signature': 3}},
#     'Reflection #6': {'track_id': '320tyiyb2coDlvBvkFY0Zy',
#      'disc_number': 1,
#      'duration_ms': 114429,
#      'track_number': 6,
#      'audio_information': {'danceability': 0.567,
#       'energy': 0.424,
#       'key': 7,
#       'loudness': -13.059,
#       'mode': 1,
#       'speechiness': 0.0365,
#       'acousticness': 0.845,
#       'instrumentalness': 0.98,
#       'liveness': 0.115,
#       'valence': 0.309,
#       'tempo': 111.084,
# ...
#    'release_date': '2005',
#    'total_tracks': 10,
#    'tracklist': {'Empty': {'track_id': '3wNUaKeGPWmbB7139pfZdj',
#      'disc_number': 1,
#      'duration_ms': 355066,
#      'track_number': 1,
#      'audio_information': {'danceability': 0.6,
#       'energy': 0.6,
#       'key': 4,
#       'loudness': -8.199,
#       'mode': 0,
#       'speechiness': 0.0453,
#       'acousticness': 0.0206,
#       'instrumentalness': 0.758,
#       'liveness': 0.0817,
#       'valence': 0.358,
#       'tempo': 145.993,
#       'type': 'audio_features',
#       'id': '3wNUaKeGPWmbB7139pfZdj',
#       'uri': 'spotify:track:3wNUaKeGPWmbB7139pfZdj',
#       'track_href': 'https://api.spotify.com/v1/tracks/3wNUaKeGPWmbB7139pfZdj',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3wNUaKeGPWmbB7139pfZdj',
#       'duration_ms': 355067,
#       'time_signature': 4}},
#     'Glass Ceiling': {'track_id': '6wvQUcZSgcmktLPKMnBiWs',
#      'disc_number': 1,
#      'duration_ms': 235600,
#      'track_number': 2,
#      'audio_information': {'danceability': 0.592,
#       'energy': 0.977,
#       'key': 0,
#       'loudness': -3.604,
#       'mode': 1,
#       'speechiness': 0.0489,
#       'acousticness': 0.00314,
#       'instrumentalness': 0.295,
#       'liveness': 0.103,
#       'valence': 0.456,
#       'tempo': 124.059,
#       'type': 'audio_features',
#       'id': '6wvQUcZSgcmktLPKMnBiWs',
#       'uri': 'spotify:track:6wvQUcZSgcmktLPKMnBiWs',
#       'track_href': 'https://api.spotify.com/v1/tracks/6wvQUcZSgcmktLPKMnBiWs',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6wvQUcZSgcmktLPKMnBiWs',
#       'duration_ms': 235600,
#       'time_signature': 4}},
#     'Handshakes': {'track_id': '0J6f1QOUZXERhhpn2o8Xxf',
#      'disc_number': 1,
#      'duration_ms': 186226,
#      'track_number': 3,
#      'audio_information': {'danceability': 0.416,
#       'energy': 0.987,
#       'key': 5,
#       'loudness': -3.748,
#       'mode': 0,
#       'speechiness': 0.12,
#       'acousticness': 0.00485,
#       'instrumentalness': 0.127,
#       'liveness': 0.349,
#       'valence': 0.527,
#       'tempo': 158.102,
#       'type': 'audio_features',
#       'id': '0J6f1QOUZXERhhpn2o8Xxf',
#       'uri': 'spotify:track:0J6f1QOUZXERhhpn2o8Xxf',
#       'track_href': 'https://api.spotify.com/v1/tracks/0J6f1QOUZXERhhpn2o8Xxf',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0J6f1QOUZXERhhpn2o8Xxf',
#       'duration_ms': 186227,
#       'time_signature': 4}},
#     'Too Little Too Late': {'track_id': '3Gk8YeEo7mO6lYpM6iwgu5',
#      'disc_number': 1,
#      'duration_ms': 262146,
#      'track_number': 4,
#      'audio_information': {'danceability': 0.803,
#       'energy': 0.619,
#       'key': 0,
#       'loudness': -5.63,
#       'mode': 1,
#       'speechiness': 0.0407,
#       'acousticness': 0.00787,
#       'instrumentalness': 0.0255,
#       'liveness': 0.0899,
#       'valence': 0.768,
#       'tempo': 121.03,
#       'type': 'audio_features',
#       'id': '3Gk8YeEo7mO6lYpM6iwgu5',
#       'uri': 'spotify:track:3Gk8YeEo7mO6lYpM6iwgu5',
#       'track_href': 'https://api.spotify.com/v1/tracks/3Gk8YeEo7mO6lYpM6iwgu5',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3Gk8YeEo7mO6lYpM6iwgu5',
#       'duration_ms': 262147,
#       'time_signature': 4}},
#     'Poster Of A Girl': {'track_id': '0aE8OHdAwCOxbyJhQrF6on',
#      'disc_number': 1,
#      'duration_ms': 284720,
#      'track_number': 5,
#      'audio_information': {'danceability': 0.571,
#       'energy': 0.862,
#       'key': 8,
#       'loudness': -4.483,
#       'mode': 0,
#       'speechiness': 0.0316,
#       'acousticness': 0.00898,
#       'instrumentalness': 0.0429,
#       'liveness': 0.0825,
#       'valence': 0.615,
#       'tempo': 120.003,
#       'type': 'audio_features',
#       'id': '0aE8OHdAwCOxbyJhQrF6on',
#       'uri': 'spotify:track:0aE8OHdAwCOxbyJhQrF6on',
#       'track_href': 'https://api.spotify.com/v1/tracks/0aE8OHdAwCOxbyJhQrF6on',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0aE8OHdAwCOxbyJhQrF6on',
#       'duration_ms': 284720,
#       'time_signature': 4}},
#     'Monster Hospital': {'track_id': '2R45UHd0OXkfNU8DkfvC3s',
#      'disc_number': 1,
#      'duration_ms': 210466,
#      'track_number': 6,
#      'audio_information': {'danceability': 0.43,
#       'energy': 0.978,
#       'key': 2,
#       'loudness': -3.61,
#       'mode': 1,
#       'speechiness': 0.0697,
#       'acousticness': 0.00048,
#       'instrumentalness': 0.201,
#       'liveness': 0.376,
#       'valence': 0.732,
#       'tempo': 162.088,
#       'type': 'audio_features',
#       'id': '2R45UHd0OXkfNU8DkfvC3s',
#       'uri': 'spotify:track:2R45UHd0OXkfNU8DkfvC3s',
#       'track_href': 'https://api.spotify.com/v1/tracks/2R45UHd0OXkfNU8DkfvC3s',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2R45UHd0OXkfNU8DkfvC3s',
#       'duration_ms': 210467,
#       'time_signature': 4}},
#     'Patriarch On a Vespa': {'track_id': '7mrpDOANT2YMCZ31hfh8V7',
#      'disc_number': 1,
#      'duration_ms': 272786,
#      'track_number': 7,
#      'audio_information': {'danceability': 0.433,
#       'energy': 0.978,
#       'key': 8,
#       'loudness': -4.683,
#       'mode': 1,
#       'speechiness': 0.112,
#       'acousticness': 0.000194,
#       'instrumentalness': 0.438,
#       'liveness': 0.135,
#       'valence': 0.127,
#       'tempo': 158.403,
#       'type': 'audio_features',
#       'id': '7mrpDOANT2YMCZ31hfh8V7',
#       'uri': 'spotify:track:7mrpDOANT2YMCZ31hfh8V7',
#       'track_href': 'https://api.spotify.com/v1/tracks/7mrpDOANT2YMCZ31hfh8V7',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7mrpDOANT2YMCZ31hfh8V7',
#       'duration_ms': 272787,
#       'time_signature': 4}},
#     'The Police and the Private': {'track_id': '5Fkd5VD3C6kAthCT524yrd',
#      'disc_number': 1,
#      'duration_ms': 223880,
#      'track_number': 8,
#      'audio_information': {'danceability': 0.519,
#       'energy': 0.547,
#       'key': 10,
#       'loudness': -9.023,
#       'mode': 1,
#       'speechiness': 0.0337,
#       'acousticness': 0.854,
#       'instrumentalness': 0.000258,
#       'liveness': 0.286,
#       'valence': 0.501,
#       'tempo': 128.0,
#       'type': 'audio_features',
#       'id': '5Fkd5VD3C6kAthCT524yrd',
#       'uri': 'spotify:track:5Fkd5VD3C6kAthCT524yrd',
#       'track_href': 'https://api.spotify.com/v1/tracks/5Fkd5VD3C6kAthCT524yrd',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5Fkd5VD3C6kAthCT524yrd',
#       'duration_ms': 223880,
#       'time_signature': 4}},
#     'Ending Start': {'track_id': '4ciGMWvhB46SZ1oxb7GxaZ',
#      'disc_number': 1,
#      'duration_ms': 200106,
#      'track_number': 9,
#      'audio_information': {'danceability': 0.42,
#       'energy': 0.646,
#       'key': 4,
#       'loudness': -8.596,
#       'mode': 1,
#       'speechiness': 0.0368,
#       'acousticness': 0.031,
#       'instrumentalness': 0.0161,
#       'liveness': 0.316,
#       'valence': 0.0669,
#       'tempo': 144.874,
#       'type': 'audio_features',
#       'id': '4ciGMWvhB46SZ1oxb7GxaZ',
#       'uri': 'spotify:track:4ciGMWvhB46SZ1oxb7GxaZ',
#       'track_href': 'https://api.spotify.com/v1/tracks/4ciGMWvhB46SZ1oxb7GxaZ',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4ciGMWvhB46SZ1oxb7GxaZ',
#       'duration_ms': 200107,
#       'time_signature': 3}},
#     'Live It Out': {'track_id': '1BLhYLy5Zg3NSxVCXUkv9o',
#      'disc_number': 1,
#      'duration_ms': 223840,
#      'track_number': 10,
#      'audio_information': {'danceability': 0.426,
#       'energy': 0.92,
#       'key': 0,
#       'loudness': -6.147,
#       'mode': 1,
#       'speechiness': 0.0851,
#       'acousticness': 0.000514,
#       'instrumentalness': 0.0525,
#       'liveness': 0.295,
#       'valence': 0.489,
#       'tempo': 171.967,
#       'type': 'audio_features',
#       'id': '1BLhYLy5Zg3NSxVCXUkv9o',
#       'uri': 'spotify:track:1BLhYLy5Zg3NSxVCXUkv9o',
#       'track_href': 'https://api.spotify.com/v1/tracks/1BLhYLy5Zg3NSxVCXUkv9o',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1BLhYLy5Zg3NSxVCXUkv9o',
#       'duration_ms': 223840,
#       'time_signature': 4}}},
#    'label': 'Last Gang'},
#   'Old World Underground, Where Are You Now?': {'album_id': '4LileDrFwEUFB5UPA3AEia',
#    'release_date': '2003-09-01',
#    'total_tracks': 10,
#    'tracklist': {'IOU': {'track_id': '6SzU8PXnwz0hEULfJ461XF',
#      'disc_number': 1,
#      'duration_ms': 262173,
#      'track_number': 1,
#      'audio_information': {'danceability': 0.52,
#       'energy': 0.746,
#       'key': 11,
#       'loudness': -7.565,
#       'mode': 0,
#       'speechiness': 0.0277,
#       'acousticness': 0.0154,
#       'instrumentalness': 0.0383,
#       'liveness': 0.149,
#       'valence': 0.689,
#       'tempo': 157.088,
#       'type': 'audio_features',
#       'id': '6SzU8PXnwz0hEULfJ461XF',
#       'uri': 'spotify:track:6SzU8PXnwz0hEULfJ461XF',
#       'track_href': 'https://api.spotify.com/v1/tracks/6SzU8PXnwz0hEULfJ461XF',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6SzU8PXnwz0hEULfJ461XF',
#       'duration_ms': 262173,
#       'time_signature': 4}},
#     'Hustle Rose': {'track_id': '4jZd3y5u9p03uI13Q1ME3j',
#      'disc_number': 1,
#      'duration_ms': 333426,
#      'track_number': 2,
#      'audio_information': {'danceability': 0.618,
#       'energy': 0.785,
#       'key': 2,
#       'loudness': -9.187,
#       'mode': 1,
#       'speechiness': 0.0329,
#       'acousticness': 0.00452,
#       'instrumentalness': 0.433,
#       'liveness': 0.199,
#       'valence': 0.379,
#       'tempo': 114.119,
#       'type': 'audio_features',
#       'id': '4jZd3y5u9p03uI13Q1ME3j',
#       'uri': 'spotify:track:4jZd3y5u9p03uI13Q1ME3j',
#       'track_href': 'https://api.spotify.com/v1/tracks/4jZd3y5u9p03uI13Q1ME3j',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4jZd3y5u9p03uI13Q1ME3j',
#       'duration_ms': 333427,
#       'time_signature': 4}},
#     'Succexy': {'track_id': '5JbZXoGXj1Ro7vXrvSnKc8',
#      'disc_number': 1,
#      'duration_ms': 185306,
#      'track_number': 3,
#      'audio_information': {'danceability': 0.651,
#       'energy': 0.752,
#       'key': 11,
#       'loudness': -6.866,
#       'mode': 0,
#       'speechiness': 0.0295,
#       'acousticness': 0.00512,
#       'instrumentalness': 0.00279,
#       'liveness': 0.318,
#       'valence': 0.971,
#       'tempo': 140.139,
#       'type': 'audio_features',
#       'id': '5JbZXoGXj1Ro7vXrvSnKc8',
#       'uri': 'spotify:track:5JbZXoGXj1Ro7vXrvSnKc8',
#       'track_href': 'https://api.spotify.com/v1/tracks/5JbZXoGXj1Ro7vXrvSnKc8',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5JbZXoGXj1Ro7vXrvSnKc8',
#       'duration_ms': 185307,
#       'time_signature': 4}},
#     'Combat Baby': {'track_id': '2QJ9dLiolwZNPl5etYP2MI',
#      'disc_number': 1,
#      'duration_ms': 209760,
#      'track_number': 4,
#      'audio_information': {'danceability': 0.649,
#       'energy': 0.914,
#       'key': 9,
#       'loudness': -6.199,
#       'mode': 1,
#       'speechiness': 0.0455,
#       'acousticness': 0.00573,
#       'instrumentalness': 0.000165,
#       'liveness': 0.0997,
#       'valence': 0.739,
#       'tempo': 139.123,
#       'type': 'audio_features',
#       'id': '2QJ9dLiolwZNPl5etYP2MI',
#       'uri': 'spotify:track:2QJ9dLiolwZNPl5etYP2MI',
#       'track_href': 'https://api.spotify.com/v1/tracks/2QJ9dLiolwZNPl5etYP2MI',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2QJ9dLiolwZNPl5etYP2MI',
#       'duration_ms': 209760,
#       'time_signature': 4}},
#     'Calculation Theme': {'track_id': '5BYYPgwikCIGbQLKuPIpIw',
#      'disc_number': 1,
#      'duration_ms': 211706,
#      'track_number': 5,
#      'audio_information': {'danceability': 0.397,
#       'energy': 0.0842,
#       'key': 0,
#       'loudness': -17.068,
#       'mode': 1,
#       'speechiness': 0.0385,
#       'acousticness': 0.984,
#       'instrumentalness': 5.89e-05,
#       'liveness': 0.108,
#       'valence': 0.516,
#       'tempo': 53.897,
#       'type': 'audio_features',
#       'id': '5BYYPgwikCIGbQLKuPIpIw',
#       'uri': 'spotify:track:5BYYPgwikCIGbQLKuPIpIw',
#       'track_href': 'https://api.spotify.com/v1/tracks/5BYYPgwikCIGbQLKuPIpIw',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5BYYPgwikCIGbQLKuPIpIw',
#       'duration_ms': 211707,
#       'time_signature': 4}},
#     'Wet Blanket': {'track_id': '3Bz2xHUIF9uDX4mXBwlAtM',
#      'disc_number': 1,
#      'duration_ms': 247693,
#      'track_number': 6,
#      'audio_information': {'danceability': 0.582,
#       'energy': 0.847,
#       'key': 10,
#       'loudness': -5.601,
#       'mode': 1,
#       'speechiness': 0.0279,
#       'acousticness': 0.00365,
#       'instrumentalness': 0.0647,
#       'liveness': 0.323,
#       'valence': 0.96,
#       'tempo': 146.154,
#       'type': 'audio_features',
#       'id': '3Bz2xHUIF9uDX4mXBwlAtM',
#       'uri': 'spotify:track:3Bz2xHUIF9uDX4mXBwlAtM',
#       'track_href': 'https://api.spotify.com/v1/tracks/3Bz2xHUIF9uDX4mXBwlAtM',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3Bz2xHUIF9uDX4mXBwlAtM',
#       'duration_ms': 247693,
#       'time_signature': 4}},
#     'On a Slow Night': {'track_id': '3fm22HijCFaNbPP3tXbUfz',
#      'disc_number': 1,
#      'duration_ms': 276533,
#      'track_number': 7,
#      'audio_information': {'danceability': 0.548,
#       'energy': 0.33,
#       'key': 6,
#       'loudness': -10.552,
#       'mode': 1,
#       'speechiness': 0.0297,
#       'acousticness': 0.0788,
#       'instrumentalness': 0.00949,
#       'liveness': 0.0878,
#       'valence': 0.189,
#       'tempo': 140.238,
#       'type': 'audio_features',
#       'id': '3fm22HijCFaNbPP3tXbUfz',
#       'uri': 'spotify:track:3fm22HijCFaNbPP3tXbUfz',
#       'track_href': 'https://api.spotify.com/v1/tracks/3fm22HijCFaNbPP3tXbUfz',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3fm22HijCFaNbPP3tXbUfz',
#       'duration_ms': 276533,
#       'time_signature': 4}},
#     'The List': {'track_id': '64FJo9BIowKBHkwiIpZqbN',
#      'disc_number': 1,
#      'duration_ms': 172706,
#      'track_number': 8,
#      'audio_information': {'danceability': 0.475,
#       'energy': 0.721,
#       'key': 2,
#       'loudness': -7.435,
#       'mode': 1,
#       'speechiness': 0.0339,
#       'acousticness': 0.00182,
#       'instrumentalness': 2.37e-05,
#       'liveness': 0.0688,
#       'valence': 0.438,
#       'tempo': 149.417,
#       'type': 'audio_features',
#       'id': '64FJo9BIowKBHkwiIpZqbN',
#       'uri': 'spotify:track:64FJo9BIowKBHkwiIpZqbN',
#       'track_href': 'https://api.spotify.com/v1/tracks/64FJo9BIowKBHkwiIpZqbN',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/64FJo9BIowKBHkwiIpZqbN',
#       'duration_ms': 172707,
#       'time_signature': 4}},
#     'Dead Disco': {'track_id': '0vJPVfyCJ0WwrBQ71FP23s',
#      'disc_number': 1,
#      'duration_ms': 205533,
#      'track_number': 9,
#      'audio_information': {'danceability': 0.52,
#       'energy': 0.844,
#       'key': 5,
#       'loudness': -6.8,
#       'mode': 0,
#       'speechiness': 0.0315,
#       'acousticness': 5.16e-05,
#       'instrumentalness': 0.0104,
#       'liveness': 0.325,
#       'valence': 0.666,
#       'tempo': 138.444,
#       'type': 'audio_features',
#       'id': '0vJPVfyCJ0WwrBQ71FP23s',
#       'uri': 'spotify:track:0vJPVfyCJ0WwrBQ71FP23s',
#       'track_href': 'https://api.spotify.com/v1/tracks/0vJPVfyCJ0WwrBQ71FP23s',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0vJPVfyCJ0WwrBQ71FP23s',
#       'duration_ms': 205533,
#       'time_signature': 4}},
#     'Love Is A Place': {'track_id': '4oy15zUDqIRU2gnQES9F49',
#      'disc_number': 1,
#      'duration_ms': 129293,
#      'track_number': 10,
#      'audio_information': {'danceability': 0.583,
#       'energy': 0.311,
#       'key': 2,
#       'loudness': -12.996,
#       'mode': 1,
#       'speechiness': 0.0324,
#       'acousticness': 0.976,
#       'instrumentalness': 0.823,
#       'liveness': 0.112,
#       'valence': 0.413,
#       'tempo': 155.934,
#       'type': 'audio_features',
#       'id': '4oy15zUDqIRU2gnQES9F49',
#       'uri': 'spotify:track:4oy15zUDqIRU2gnQES9F49',
#       'track_href': 'https://api.spotify.com/v1/tracks/4oy15zUDqIRU2gnQES9F49',
#       'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4oy15zUDqIRU2gnQES9F49',
#       'duration_ms': 129293,
#       'time_signature': 4}}},
#    'label': 'Everloving Records'}}}

# %% [markdown]
# ## Get song lyrics from genius using spotify artist name and song name
# The idea here is that if we match on both fields, it is a song we want.

# %% [markdown]
# ## Save current work to json file

# %%
# with open('spotify_artist_data.json', 'w') as outfile:
#     json.dump(spotify_artist_data, outfile)

# To Read
# f = open('spotify_artist_data.json')
# data = json.load(f)
# f.close()
